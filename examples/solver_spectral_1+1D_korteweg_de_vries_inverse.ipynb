# %% [markdown]
# # (1+1)D Korteweg–De Vries (KdV) Equation with Physics-Informed Neural Networks
#
# The **KdV equation** models the dynamics of solitary waves (solitons):
#
# $$u_t + \eta\, u\, u_x + \mu^2\, u_{xxx} = 0, \quad t \in (0, 1),\ x \in (-1, 1)$$
#
# **Initial condition:**
# $$u(x, 0) = \cos(\pi x)$$
#
# **Periodic boundary conditions:**
# $$u(t, -1) = u(t, 1)$$
#
# **Classical parameters** (η = 1, μ = 0.022).

# %%
import pinns

import numpy as np
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %% [markdown]
# # Reference Solution (spectral ETD2RK)
#
# The KdV equation with periodic BCs is solved via `DomainCubic` + `ModelSpectralSolver`.
# In Fourier space:
#
# $$\partial_t \hat{u}_k = \underbrace{i\mu^2 k^3 \hat{u}_k}_{\text{linear — exact}} + \underbrace{-\frac{i\eta k}{2}\widehat{u^2}_k}_{\text{nonlinear — ETD2RK}}$$
#
# The linear dispersion term is integrated exactly; `IntegratorETD2RK` uses `jax.lax.scan` and is fully differentiable for inverse problems.

# %%
eta_val = 1.0
mu_val  = 0.022
Nx = 512
Nt = 200

t_ref = np.linspace(0, 1, Nt)

# ── DomainCubic (periodic, Fourier basis) ────────────────────────────────────
domain_grid = pinns.DomainCubic(
    space=[(-1.0, 1.0)],
    time=(0.0, 1.0),
)

# ── ModelSpectralSolver ───────────────────────────────────────────────────────
# x, k, forward/inverse live on the model, not on DomainCubic.
integrator = pinns.IntegratorETD2RK(dt=5e-4)
model_solver = pinns.ModelSpectralSolver(domain_grid, ["u"], integrator, shape=(Nx,))

x_ref = np.array(model_solver._grids[0])   # (Nx,) periodic nodes

# Linear part:  L_k = i·μ²·k³   (X = k, wavenumbers)
model_solver.set_linear_op(
    lambda X, p: {"u": 1j * p["mu2"] * X * (X**2)}
)

# Nonlinear part:  N(U)_k = -i·η·k/2 · FFT(u²)  (X = k, U = state dict)
def kdv_nonlinear(X, U, p):
    u = model_solver.inverse(U["u"])
    return {"u": -1j * p["eta"] / 2.0 * X * model_solver.forward(u * u)}

model_solver.set_nonlinear_op(kdv_nonlinear)
model_solver.add_parameter("eta", eta_val)
model_solver.add_parameter("mu2", mu_val**2)

# Initial condition  u(x, 0) = cos(πx)
model_solver.add_initial(jnp.cos(jnp.pi * jnp.array(x_ref)))

# ── Forward solve  (dt=5e-4 → 2000 steps) ───────────────────────────────────
U_etd = model_solver.solve(t_obs=t_ref)

# %% [markdown]
# # Inverse Problem: recovering $\mu$ from observations
#
# We now treat $\mu$ as unknown and recover it by minimising the MSE between
# the ETD2RK forward solve and noisy observations.  Because `ModelSpectralSolver.apply()`
# is built on `jax.lax.scan` + bilinear interpolation, the entire chain is
# differentiable end-to-end — no adjoint derivation needed.
#
# $$\min_{\mu} \; \frac{1}{N_t N_x} \sum_{n,i} \bigl(u^{\text{pred}}_{n,i}(\mu) - u^{\text{obs}}_{n,i}\bigr)^2$$
#
# **Pattern:** build a `Dataset` from the observations, pass it to `Trainer(model, dataset=dataset)`,
# and tell the trainer which model parameters to optimise via `fit_model_parameters=["mu"]`.
# All other parameters (`eta`) are automatically frozen via `stop_gradient`.

# %%
# ── Noisy observations (1% Gaussian noise on the reference) ─────────────────
U_ref   = np.array(U_etd["u"])   # (Nt, Nx) physical space
rng_np  = np.random.default_rng(42)
U_noisy = U_ref + rng_np.normal(0, 0.01, U_ref.shape)

# ── ModelSpectralSolver with μ as to-be-inferred parameter ───────────────────
integrator_inv = pinns.IntegratorETD2RK(dt=5e-4, checkpoint=True)
model_inv = pinns.ModelSpectralSolver(domain_grid, ["u"], integrator_inv, shape=(Nx,))

model_inv.set_linear_op(
    lambda X, p: {"u": 1j * p["mu"] ** 2 * X * (X**2)}
)

def kdv_nonlinear_inv(X, U, p):
    u = model_inv.inverse(U["u"])
    return {"u": -1j * p["eta"] / 2.0 * X * model_inv.forward(u * u)}

model_inv.set_nonlinear_op(kdv_nonlinear_inv)
model_inv.add_parameter("eta", eta_val)
model_inv.add_parameter("mu",  0.04)   # initial guess
model_inv.add_initial(jnp.cos(jnp.pi * jnp.array(x_ref)))

# Observation times are needed by ModelSpectralSolver.apply for interpolation.
model_inv._obs_times = t_ref

# ── Dataset: scatter (x, t) observation points ──────────────────────────────
# Convention: columns = [x, t]  (spatial first, time last)
T_grid, X_grid = np.meshgrid(t_ref, x_ref, indexing="ij")   # (Nt, Nx)
X_obs      = np.stack([X_grid.ravel(), T_grid.ravel()], axis=-1).astype(np.float32)
U_obs_flat = U_noisy.ravel().astype(np.float32)

idx = rng_np.choice(len(X_obs), size=4096, replace=False)
dataset = pinns.Dataset()
dataset.add_points(X_obs[idx], U_obs_flat[idx], name="obs", component=0)

# ── Reference solution interpolant (ETD2RK ground truth) ────────────────────
from scipy.interpolate import RegularGridInterpolator

_u_ref_interp = RegularGridInterpolator(
    (t_ref, x_ref), U_ref, method="linear", bounds_error=False, fill_value=None
)

def u_reference(xy, params=None):
    """Interpolate ETD2RK reference onto arbitrary (x, t) points.
    xy: (N, 2) array with columns [x_spatial, t]."""
    xt = np.column_stack([xy[:, 1], xy[:, 0]])   # flip to (t, x) for interp
    return _u_ref_interp(xt).reshape(-1, 1)

# ── Trainer (no PDE problem — dataset-only inverse) ──────────────────────────
from pinns.trainer.optimizers import AdamOptimizer

trainer = pinns.Trainer(model_inv, dataset=dataset)
trainer.set_solution(u_reference)
trainer.set_solution_parameter("mu", mu_val)   # true μ = 0.022 shown as reference line
trainer.compile(
    fit_model_parameters=["mu"],
    optimizer=AdamOptimizer(learning_rate=5e-3),
    epochs=150,
    print_each=1,
)
trainer.train()
# Out:
# Starting training for 150 epochs (JIT-compiled)...
# Epoch 0/150 | Loss: 3.83e-01 | MSE: 3.83e-01 | Terms: [] | Data: [obs: 3.83e-01] | Error: N/A | Params: [mu: 0.04] | Time: 0.0s
# Epoch 1/150 | Loss: 3.40e-01 | MSE: 3.40e-01 | Terms: [] | Data: [obs: 3.40e-01] | Error: N/A | Params: [mu: 0.035] | Time: 17.0s
# Epoch 2/150 | Loss: 3.18e-01 | MSE: 3.18e-01 | Terms: [] | Data: [obs: 3.18e-01] | Error: N/A | Params: [mu: 0.0310422] | Time: 32.7s
# Epoch 3/150 | Loss: 2.80e-01 | MSE: 2.80e-01 | Terms: [] | Data: [obs: 2.80e-01] | Error: N/A | Params: [mu: 0.0267216] | Time: 45.6s
# Epoch 4/150 | Loss: 3.63e-03 | MSE: 3.63e-03 | Terms: [] | Data: [obs: 3.63e-03] | Error: N/A | Params: [mu: 0.0222475] | Time: 46.3s
# Epoch 5/150 | Loss: 3.07e-01 | MSE: 3.07e-01 | Terms: [] | Data: [obs: 3.07e-01] | Error: N/A | Params: [mu: 0.0178735] | Time: 46.9s
# Epoch 6/150 | Loss: 3.28e-01 | MSE: 3.28e-01 | Terms: [] | Data: [obs: 3.28e-01] | Error: N/A | Params: [mu: 0.0155033] | Time: 47.6s
# Epoch 7/150 | Loss: 3.50e-01 | MSE: 3.50e-01 | Terms: [] | Data: [obs: 3.50e-01] | Error: N/A | Params: [mu: 0.0141807] | Time: 48.2s
# Epoch 8/150 | Loss: 3.42e-01 | MSE: 3.42e-01 | Terms: [] | Data: [obs: 3.42e-01] | Error: N/A | Params: [mu: 0.0130548] | Time: 48.9s
# Epoch 9/150 | Loss: 4.04e-01 | MSE: 4.04e-01 | Terms: [] | Data: [obs: 4.04e-01] | Error: N/A | Params: [mu: 0.0115189] | Time: 49.5s
# Epoch 10/150 | Loss: 3.42e-01 | MSE: 3.42e-01 | Terms: [] | Data: [obs: 3.42e-01] | Error: N/A | Params: [mu: 0.0131] | Time: 50.3s
# Epoch 11/150 | Loss: 3.50e-01 | MSE: 3.50e-01 | Terms: [] | Data: [obs: 3.50e-01] | Error: N/A | Params: [mu: 0.0140934] | Time: 51.0s
# Epoch 12/150 | Loss: 3.37e-01 | MSE: 3.37e-01 | Terms: [] | Data: [obs: 3.37e-01] | Error: N/A | Params: [mu: 0.0150511] | Time: 51.6s
# Epoch 13/150 | Loss: 3.25e-01 | MSE: 3.25e-01 | Terms: [] | Data: [obs: 3.25e-01] | Error: N/A | Params: [mu: 0.0165298] | Time: 52.3s
# Epoch 14/150 | Loss: 3.04e-01 | MSE: 3.04e-01 | Terms: [] | Data: [obs: 3.04e-01] | Error: N/A | Params: [mu: 0.0180966] | Time: 52.9s
# Epoch 15/150 | Loss: 2.03e-01 | MSE: 2.03e-01 | Terms: [] | Data: [obs: 2.03e-01] | Error: N/A | Params: [mu: 0.0198347] | Time: 53.6s
# Epoch 16/150 | Loss: 2.35e-02 | MSE: 2.35e-02 | Terms: [] | Data: [obs: 2.35e-02] | Error: N/A | Params: [mu: 0.0226651] | Time: 54.2s
# Epoch 17/150 | Loss: 1.54e-01 | MSE: 1.54e-01 | Terms: [] | Data: [obs: 1.54e-01] | Error: N/A | Params: [mu: 0.0241012] | Time: 54.9s
# Epoch 18/150 | Loss: 1.48e-01 | MSE: 1.48e-01 | Terms: [] | Data: [obs: 1.48e-01] | Error: N/A | Params: [mu: 0.0240409] | Time: 55.6s
# Epoch 19/150 | Loss: 4.05e-02 | MSE: 4.05e-02 | Terms: [] | Data: [obs: 4.05e-02] | Error: N/A | Params: [mu: 0.0229011] | Time: 56.4s
# Epoch 20/150 | Loss: 5.18e-02 | MSE: 5.18e-02 | Terms: [] | Data: [obs: 5.18e-02] | Error: N/A | Params: [mu: 0.0210738] | Time: 57.0s
# Epoch 21/150 | Loss: 1.08e-01 | MSE: 1.08e-01 | Terms: [] | Data: [obs: 1.08e-01] | Error: N/A | Params: [mu: 0.0205937] | Time: 57.7s
# Epoch 22/150 | Loss: 2.84e-02 | MSE: 2.84e-02 | Terms: [] | Data: [obs: 2.84e-02] | Error: N/A | Params: [mu: 0.0213239] | Time: 58.3s
# Epoch 23/150 | Loss: 2.41e-02 | MSE: 2.41e-02 | Terms: [] | Data: [obs: 2.41e-02] | Error: N/A | Params: [mu: 0.022675] | Time: 59.0s
# Epoch 24/150 | Loss: 7.68e-02 | MSE: 7.68e-02 | Terms: [] | Data: [obs: 7.68e-02] | Error: N/A | Params: [mu: 0.0233134] | Time: 59.7s
# Epoch 25/150 | Loss: 5.55e-02 | MSE: 5.55e-02 | Terms: [] | Data: [obs: 5.55e-02] | Error: N/A | Params: [mu: 0.0230809] | Time: 60.3s
# Epoch 26/150 | Loss: 1.77e-03 | MSE: 1.77e-03 | Terms: [] | Data: [obs: 1.77e-03] | Error: N/A | Params: [mu: 0.0221692] | Time: 61.0s
# Epoch 27/150 | Loss: 4.14e-02 | MSE: 4.14e-02 | Terms: [] | Data: [obs: 4.14e-02] | Error: N/A | Params: [mu: 0.0211776] | Time: 61.6s
# Epoch 28/150 | Loss: 5.18e-02 | MSE: 5.18e-02 | Terms: [] | Data: [obs: 5.18e-02] | Error: N/A | Params: [mu: 0.0210731] | Time: 62.4s
# Epoch 29/150 | Loss: 3.03e-03 | MSE: 3.03e-03 | Terms: [] | Data: [obs: 3.03e-03] | Error: N/A | Params: [mu: 0.0217829] | Time: 63.1s
# Epoch 30/150 | Loss: 2.19e-02 | MSE: 2.19e-02 | Terms: [] | Data: [obs: 2.19e-02] | Error: N/A | Params: [mu: 0.0226406] | Time: 63.7s
# Epoch 31/150 | Loss: 4.21e-02 | MSE: 4.21e-02 | Terms: [] | Data: [obs: 4.21e-02] | Error: N/A | Params: [mu: 0.0229211] | Time: 64.4s
# Epoch 32/150 | Loss: 1.68e-02 | MSE: 1.68e-02 | Terms: [] | Data: [obs: 1.68e-02] | Error: N/A | Params: [mu: 0.0225547] | Time: 65.0s
# Epoch 33/150 | Loss: 2.85e-03 | MSE: 2.85e-03 | Terms: [] | Data: [obs: 2.85e-03] | Error: N/A | Params: [mu: 0.0217898] | Time: 65.7s
# Epoch 34/150 | Loss: 3.06e-02 | MSE: 3.06e-02 | Terms: [] | Data: [obs: 3.06e-02] | Error: N/A | Params: [mu: 0.0212979] | Time: 66.3s
# Epoch 35/150 | Loss: 1.51e-02 | MSE: 1.51e-02 | Terms: [] | Data: [obs: 1.51e-02] | Error: N/A | Params: [mu: 0.0215094] | Time: 67.0s
# Epoch 36/150 | Loss: 1.77e-03 | MSE: 1.77e-03 | Terms: [] | Data: [obs: 1.77e-03] | Error: N/A | Params: [mu: 0.0221691] | Time: 67.8s
# Epoch 37/150 | Loss: 2.05e-02 | MSE: 2.05e-02 | Terms: [] | Data: [obs: 2.05e-02] | Error: N/A | Params: [mu: 0.0226183] | Time: 68.5s
# Epoch 38/150 | Loss: 1.63e-02 | MSE: 1.63e-02 | Terms: [] | Data: [obs: 1.63e-02] | Error: N/A | Params: [mu: 0.0225452] | Time: 69.1s
# Epoch 39/150 | Loss: 2.15e-04 | MSE: 2.15e-04 | Terms: [] | Data: [obs: 2.15e-04] | Error: N/A | Params: [mu: 0.0220448] | Time: 69.8s
# Epoch 40/150 | Loss: 1.29e-02 | MSE: 1.29e-02 | Terms: [] | Data: [obs: 1.29e-02] | Error: N/A | Params: [mu: 0.0215467] | Time: 70.4s
# Epoch 41/150 | Loss: 1.30e-02 | MSE: 1.30e-02 | Terms: [] | Data: [obs: 1.30e-02] | Error: N/A | Params: [mu: 0.0215461] | Time: 71.1s
# Epoch 42/150 | Loss: 1.01e-04 | MSE: 1.01e-04 | Terms: [] | Data: [obs: 1.01e-04] | Error: N/A | Params: [mu: 0.0219954] | Time: 71.8s
# Epoch 43/150 | Loss: 9.53e-03 | MSE: 9.53e-03 | Terms: [] | Data: [obs: 9.53e-03] | Error: N/A | Params: [mu: 0.0224105] | Time: 72.5s
# Epoch 44/150 | Loss: 1.04e-02 | MSE: 1.04e-02 | Terms: [] | Data: [obs: 1.04e-02] | Error: N/A | Params: [mu: 0.0224297] | Time: 73.3s
# Epoch 45/150 | Loss: 4.22e-04 | MSE: 4.22e-04 | Terms: [] | Data: [obs: 4.22e-04] | Error: N/A | Params: [mu: 0.0220744] | Time: 73.9s
# Epoch 46/150 | Loss: 6.55e-03 | MSE: 6.55e-03 | Terms: [] | Data: [obs: 6.55e-03] | Error: N/A | Params: [mu: 0.0216785] | Time: 74.6s
# Epoch 47/150 | Loss: 7.57e-03 | MSE: 7.57e-03 | Terms: [] | Data: [obs: 7.57e-03] | Error: N/A | Params: [mu: 0.0216543] | Time: 75.3s
# Epoch 48/150 | Loss: 1.02e-04 | MSE: 1.02e-04 | Terms: [] | Data: [obs: 1.02e-04] | Error: N/A | Params: [mu: 0.0219941] | Time: 76.0s
# Epoch 49/150 | Loss: 5.61e-03 | MSE: 5.61e-03 | Terms: [] | Data: [obs: 5.61e-03] | Error: N/A | Params: [mu: 0.0223106] | Time: 76.6s
# Epoch 50/150 | Loss: 5.39e-03 | MSE: 5.39e-03 | Terms: [] | Data: [obs: 5.39e-03] | Error: N/A | Params: [mu: 0.0223042] | Time: 77.3s
# Epoch 51/150 | Loss: 1.02e-04 | MSE: 1.02e-04 | Terms: [] | Data: [obs: 1.02e-04] | Error: N/A | Params: [mu: 0.022008] | Time: 78.0s
# Epoch 52/150 | Loss: 4.62e-03 | MSE: 4.62e-03 | Terms: [] | Data: [obs: 4.62e-03] | Error: N/A | Params: [mu: 0.0217307] | Time: 78.8s
# Epoch 53/150 | Loss: 3.26e-03 | MSE: 3.26e-03 | Terms: [] | Data: [obs: 3.26e-03] | Error: N/A | Params: [mu: 0.0217745] | Time: 79.5s
# Epoch 54/150 | Loss: 3.32e-04 | MSE: 3.32e-04 | Terms: [] | Data: [obs: 3.32e-04] | Error: N/A | Params: [mu: 0.0220632] | Time: 80.2s
# Epoch 55/150 | Loss: 3.98e-03 | MSE: 3.98e-03 | Terms: [] | Data: [obs: 3.98e-03] | Error: N/A | Params: [mu: 0.0222596] | Time: 80.9s
# Epoch 56/150 | Loss: 1.87e-03 | MSE: 1.87e-03 | Terms: [] | Data: [obs: 1.87e-03] | Error: N/A | Params: [mu: 0.0221743] | Time: 81.5s
# Epoch 57/150 | Loss: 5.60e-04 | MSE: 5.60e-04 | Terms: [] | Data: [obs: 5.60e-04] | Error: N/A | Params: [mu: 0.0219139] | Time: 82.2s
# Epoch 58/150 | Loss: 3.25e-03 | MSE: 3.25e-03 | Terms: [] | Data: [obs: 3.25e-03] | Error: N/A | Params: [mu: 0.021775] | Time: 82.9s
# Epoch 59/150 | Loss: 6.07e-04 | MSE: 6.07e-04 | Terms: [] | Data: [obs: 6.07e-04] | Error: N/A | Params: [mu: 0.0219096] | Time: 83.7s
# Epoch 60/150 | Loss: 1.19e-03 | MSE: 1.19e-03 | Terms: [] | Data: [obs: 1.19e-03] | Error: N/A | Params: [mu: 0.0221368] | Time: 84.4s
# Epoch 61/150 | Loss: 2.26e-03 | MSE: 2.26e-03 | Terms: [] | Data: [obs: 2.26e-03] | Error: N/A | Params: [mu: 0.0221928] | Time: 85.1s
# Epoch 62/150 | Loss: 1.59e-04 | MSE: 1.59e-04 | Terms: [] | Data: [obs: 1.59e-04] | Error: N/A | Params: [mu: 0.0220324] | Time: 85.7s
# Epoch 63/150 | Loss: 1.50e-03 | MSE: 1.50e-03 | Terms: [] | Data: [obs: 1.50e-03] | Error: N/A | Params: [mu: 0.02185] | Time: 86.4s
# Epoch 64/150 | Loss: 1.22e-03 | MSE: 1.22e-03 | Terms: [] | Data: [obs: 1.22e-03] | Error: N/A | Params: [mu: 0.0218659] | Time: 87.1s
# Epoch 65/150 | Loss: 2.11e-04 | MSE: 2.11e-04 | Terms: [] | Data: [obs: 2.11e-04] | Error: N/A | Params: [mu: 0.022044] | Time: 87.8s
# Epoch 66/150 | Loss: 1.50e-03 | MSE: 1.50e-03 | Terms: [] | Data: [obs: 1.50e-03] | Error: N/A | Params: [mu: 0.0221547] | Time: 88.6s
# Epoch 67/150 | Loss: 4.34e-04 | MSE: 4.34e-04 | Terms: [] | Data: [obs: 4.34e-04] | Error: N/A | Params: [mu: 0.0220757] | Time: 89.3s
# Epoch 68/150 | Loss: 5.59e-04 | MSE: 5.59e-04 | Terms: [] | Data: [obs: 5.59e-04] | Error: N/A | Params: [mu: 0.021914] | Time: 89.9s
# Epoch 69/150 | Loss: 1.06e-03 | MSE: 1.06e-03 | Terms: [] | Data: [obs: 1.06e-03] | Error: N/A | Params: [mu: 0.0218758] | Time: 90.6s
# Epoch 70/150 | Loss: 9.92e-05 | MSE: 9.92e-05 | Terms: [] | Data: [obs: 9.92e-05] | Error: N/A | Params: [mu: 0.0219998] | Time: 91.3s
# Epoch 71/150 | Loss: 8.56e-04 | MSE: 8.56e-04 | Terms: [] | Data: [obs: 8.56e-04] | Error: N/A | Params: [mu: 0.0221138] | Time: 92.0s
# Epoch 72/150 | Loss: 4.52e-04 | MSE: 4.52e-04 | Terms: [] | Data: [obs: 4.52e-04] | Error: N/A | Params: [mu: 0.0220778] | Time: 92.7s
# Epoch 73/150 | Loss: 2.67e-04 | MSE: 2.67e-04 | Terms: [] | Data: [obs: 2.67e-04] | Error: N/A | Params: [mu: 0.0219483] | Time: 93.3s
# Epoch 74/150 | Loss: 7.31e-04 | MSE: 7.31e-04 | Terms: [] | Data: [obs: 7.31e-04] | Error: N/A | Params: [mu: 0.0218992] | Time: 94.2s
# Epoch 75/150 | Loss: 1.07e-04 | MSE: 1.07e-04 | Terms: [] | Data: [obs: 1.07e-04] | Error: N/A | Params: [mu: 0.0219893] | Time: 94.8s
# Epoch 76/150 | Loss: 5.36e-04 | MSE: 5.36e-04 | Terms: [] | Data: [obs: 5.36e-04] | Error: N/A | Params: [mu: 0.0220864] | Time: 95.5s
# Epoch 77/150 | Loss: 3.31e-04 | MSE: 3.31e-04 | Terms: [] | Data: [obs: 3.31e-04] | Error: N/A | Params: [mu: 0.0220631] | Time: 96.2s
# Epoch 78/150 | Loss: 2.02e-04 | MSE: 2.02e-04 | Terms: [] | Data: [obs: 2.02e-04] | Error: N/A | Params: [mu: 0.0219596] | Time: 96.9s
# Epoch 79/150 | Loss: 4.80e-04 | MSE: 4.80e-04 | Terms: [] | Data: [obs: 4.80e-04] | Error: N/A | Params: [mu: 0.0219218] | Time: 97.6s
# Epoch 80/150 | Loss: 1.00e-04 | MSE: 1.00e-04 | Terms: [] | Data: [obs: 1.00e-04] | Error: N/A | Params: [mu: 0.0219967] | Time: 98.2s
# Epoch 81/150 | Loss: 3.88e-04 | MSE: 3.88e-04 | Terms: [] | Data: [obs: 3.88e-04] | Error: N/A | Params: [mu: 0.0220704] | Time: 99.1s
# Epoch 82/150 | Loss: 2.02e-04 | MSE: 2.02e-04 | Terms: [] | Data: [obs: 2.02e-04] | Error: N/A | Params: [mu: 0.0220423] | Time: 99.7s
# Epoch 83/150 | Loss: 2.04e-04 | MSE: 2.04e-04 | Terms: [] | Data: [obs: 2.04e-04] | Error: N/A | Params: [mu: 0.0219593] | Time: 100.4s
# Epoch 84/150 | Loss: 3.02e-04 | MSE: 3.02e-04 | Terms: [] | Data: [obs: 3.02e-04] | Error: N/A | Params: [mu: 0.021943] | Time: 101.1s
# Epoch 85/150 | Loss: 1.06e-04 | MSE: 1.06e-04 | Terms: [] | Data: [obs: 1.06e-04] | Error: N/A | Params: [mu: 0.0220115] | Time: 101.8s
# Epoch 86/150 | Loss: 2.97e-04 | MSE: 2.97e-04 | Terms: [] | Data: [obs: 2.97e-04] | Error: N/A | Params: [mu: 0.0220584] | Time: 102.4s
# Epoch 87/150 | Loss: 1.18e-04 | MSE: 1.18e-04 | Terms: [] | Data: [obs: 1.18e-04] | Error: N/A | Params: [mu: 0.0220186] | Time: 103.1s
# Epoch 88/150 | Loss: 2.18e-04 | MSE: 2.18e-04 | Terms: [] | Data: [obs: 2.18e-04] | Error: N/A | Params: [mu: 0.0219567] | Time: 103.9s
# Epoch 89/150 | Loss: 1.73e-04 | MSE: 1.73e-04 | Terms: [] | Data: [obs: 1.73e-04] | Error: N/A | Params: [mu: 0.021966] | Time: 104.6s
# Epoch 90/150 | Loss: 1.39e-04 | MSE: 1.39e-04 | Terms: [] | Data: [obs: 1.39e-04] | Error: N/A | Params: [mu: 0.0220266] | Time: 105.3s
# Epoch 91/150 | Loss: 2.07e-04 | MSE: 2.07e-04 | Terms: [] | Data: [obs: 2.07e-04] | Error: N/A | Params: [mu: 0.0220432] | Time: 106.0s
# Epoch 92/150 | Loss: 1.01e-04 | MSE: 1.01e-04 | Terms: [] | Data: [obs: 1.01e-04] | Error: N/A | Params: [mu: 0.0219949] | Time: 106.6s
# Epoch 93/150 | Loss: 2.00e-04 | MSE: 2.00e-04 | Terms: [] | Data: [obs: 2.00e-04] | Error: N/A | Params: [mu: 0.0219601] | Time: 107.3s
# Epoch 94/150 | Loss: 1.04e-04 | MSE: 1.04e-04 | Terms: [] | Data: [obs: 1.04e-04] | Error: N/A | Params: [mu: 0.0219916] | Time: 108.0s
# Epoch 95/150 | Loss: 1.67e-04 | MSE: 1.67e-04 | Terms: [] | Data: [obs: 1.67e-04] | Error: N/A | Params: [mu: 0.0220345] | Time: 108.8s
# Epoch 96/150 | Loss: 1.24e-04 | MSE: 1.24e-04 | Terms: [] | Data: [obs: 1.24e-04] | Error: N/A | Params: [mu: 0.0220213] | Time: 109.5s
# Epoch 97/150 | Loss: 1.33e-04 | MSE: 1.33e-04 | Terms: [] | Data: [obs: 1.33e-04] | Error: N/A | Params: [mu: 0.0219773] | Time: 110.1s
# Epoch 98/150 | Loss: 1.40e-04 | MSE: 1.40e-04 | Terms: [] | Data: [obs: 1.40e-04] | Error: N/A | Params: [mu: 0.0219749] | Time: 110.8s
# Epoch 99/150 | Loss: 1.10e-04 | MSE: 1.10e-04 | Terms: [] | Data: [obs: 1.10e-04] | Error: N/A | Params: [mu: 0.0220144] | Time: 111.5s
# Epoch 100/150 | Loss: 1.45e-04 | MSE: 1.45e-04 | Terms: [] | Data: [obs: 1.45e-04] | Error: N/A | Params: [mu: 0.0220285] | Time: 112.2s
# Epoch 101/150 | Loss: 1.00e-04 | MSE: 1.00e-04 | Terms: [] | Data: [obs: 1.00e-04] | Error: N/A | Params: [mu: 0.0219966] | Time: 112.9s
# Epoch 102/150 | Loss: 1.41e-04 | MSE: 1.41e-04 | Terms: [] | Data: [obs: 1.41e-04] | Error: N/A | Params: [mu: 0.0219746] | Time: 113.5s
# Epoch 103/150 | Loss: 9.95e-05 | MSE: 9.95e-05 | Terms: [] | Data: [obs: 9.95e-05] | Error: N/A | Params: [mu: 0.0219981] | Time: 114.3s
# Epoch 104/150 | Loss: 1.31e-04 | MSE: 1.31e-04 | Terms: [] | Data: [obs: 1.31e-04] | Error: N/A | Params: [mu: 0.022024] | Time: 115.0s
# Epoch 105/150 | Loss: 1.03e-04 | MSE: 1.03e-04 | Terms: [] | Data: [obs: 1.03e-04] | Error: N/A | Params: [mu: 0.0220089] | Time: 115.7s
# Epoch 106/150 | Loss: 1.22e-04 | MSE: 1.22e-04 | Terms: [] | Data: [obs: 1.22e-04] | Error: N/A | Params: [mu: 0.0219816] | Time: 116.4s
# Epoch 107/150 | Loss: 1.07e-04 | MSE: 1.07e-04 | Terms: [] | Data: [obs: 1.07e-04] | Error: N/A | Params: [mu: 0.0219898] | Time: 117.1s
# Epoch 108/150 | Loss: 1.13e-04 | MSE: 1.13e-04 | Terms: [] | Data: [obs: 1.13e-04] | Error: N/A | Params: [mu: 0.0220162] | Time: 117.7s
# Epoch 109/150 | Loss: 1.09e-04 | MSE: 1.09e-04 | Terms: [] | Data: [obs: 1.09e-04] | Error: N/A | Params: [mu: 0.0220138] | Time: 118.4s
# Epoch 110/150 | Loss: 1.07e-04 | MSE: 1.07e-04 | Terms: [] | Data: [obs: 1.07e-04] | Error: N/A | Params: [mu: 0.0219892] | Time: 119.2s
# Epoch 111/150 | Loss: 1.10e-04 | MSE: 1.10e-04 | Terms: [] | Data: [obs: 1.10e-04] | Error: N/A | Params: [mu: 0.0219873] | Time: 119.9s
# Epoch 112/150 | Loss: 1.04e-04 | MSE: 1.04e-04 | Terms: [] | Data: [obs: 1.04e-04] | Error: N/A | Params: [mu: 0.0220095] | Time: 120.6s
# Epoch 113/150 | Loss: 1.10e-04 | MSE: 1.10e-04 | Terms: [] | Data: [obs: 1.10e-04] | Error: N/A | Params: [mu: 0.0220143] | Time: 121.3s
# Epoch 114/150 | Loss: 1.01e-04 | MSE: 1.01e-04 | Terms: [] | Data: [obs: 1.01e-04] | Error: N/A | Params: [mu: 0.0219946] | Time: 122.0s
# Epoch 115/150 | Loss: 1.09e-04 | MSE: 1.09e-04 | Terms: [] | Data: [obs: 1.09e-04] | Error: N/A | Params: [mu: 0.0219881] | Time: 122.6s
# Epoch 116/150 | Loss: 1.00e-04 | MSE: 1.00e-04 | Terms: [] | Data: [obs: 1.00e-04] | Error: N/A | Params: [mu: 0.0220054] | Time: 123.3s
# Epoch 117/150 | Loss: 1.08e-04 | MSE: 1.08e-04 | Terms: [] | Data: [obs: 1.08e-04] | Error: N/A | Params: [mu: 0.0220128] | Time: 124.1s
# Epoch 118/150 | Loss: 9.98e-05 | MSE: 9.98e-05 | Terms: [] | Data: [obs: 9.98e-05] | Error: N/A | Params: [mu: 0.0219975] | Time: 124.8s
# Epoch 119/150 | Loss: 1.06e-04 | MSE: 1.06e-04 | Terms: [] | Data: [obs: 1.06e-04] | Error: N/A | Params: [mu: 0.0219899] | Time: 125.5s
# Epoch 120/150 | Loss: 9.96e-05 | MSE: 9.96e-05 | Terms: [] | Data: [obs: 9.96e-05] | Error: N/A | Params: [mu: 0.0220036] | Time: 126.2s
# Epoch 121/150 | Loss: 1.05e-04 | MSE: 1.05e-04 | Terms: [] | Data: [obs: 1.05e-04] | Error: N/A | Params: [mu: 0.0220107] | Time: 126.9s
# Epoch 122/150 | Loss: 9.94e-05 | MSE: 9.94e-05 | Terms: [] | Data: [obs: 9.94e-05] | Error: N/A | Params: [mu: 0.0219985] | Time: 127.5s
# Epoch 123/150 | Loss: 1.04e-04 | MSE: 1.04e-04 | Terms: [] | Data: [obs: 1.04e-04] | Error: N/A | Params: [mu: 0.0219919] | Time: 128.2s
# Epoch 124/150 | Loss: 9.94e-05 | MSE: 9.94e-05 | Terms: [] | Data: [obs: 9.94e-05] | Error: N/A | Params: [mu: 0.0220032] | Time: 129.1s
# Epoch 125/150 | Loss: 1.03e-04 | MSE: 1.03e-04 | Terms: [] | Data: [obs: 1.03e-04] | Error: N/A | Params: [mu: 0.0220089] | Time: 129.7s
# Epoch 126/150 | Loss: 9.95e-05 | MSE: 9.95e-05 | Terms: [] | Data: [obs: 9.95e-05] | Error: N/A | Params: [mu: 0.0219984] | Time: 130.4s
# Epoch 127/150 | Loss: 1.02e-04 | MSE: 1.02e-04 | Terms: [] | Data: [obs: 1.02e-04] | Error: N/A | Params: [mu: 0.0219938] | Time: 131.1s
# Epoch 128/150 | Loss: 9.96e-05 | MSE: 9.96e-05 | Terms: [] | Data: [obs: 9.96e-05] | Error: N/A | Params: [mu: 0.0220036] | Time: 131.8s
# Epoch 129/150 | Loss: 1.01e-04 | MSE: 1.01e-04 | Terms: [] | Data: [obs: 1.01e-04] | Error: N/A | Params: [mu: 0.022007] | Time: 132.5s
# Epoch 130/150 | Loss: 9.97e-05 | MSE: 9.97e-05 | Terms: [] | Data: [obs: 9.97e-05] | Error: N/A | Params: [mu: 0.0219977] | Time: 133.1s
# Epoch 131/150 | Loss: 1.01e-04 | MSE: 1.01e-04 | Terms: [] | Data: [obs: 1.01e-04] | Error: N/A | Params: [mu: 0.0219956] | Time: 133.8s
# Epoch 132/150 | Loss: 9.98e-05 | MSE: 9.98e-05 | Terms: [] | Data: [obs: 9.98e-05] | Error: N/A | Params: [mu: 0.0220043] | Time: 134.7s
# Epoch 133/150 | Loss: 1.00e-04 | MSE: 1.00e-04 | Terms: [] | Data: [obs: 1.00e-04] | Error: N/A | Params: [mu: 0.0220051] | Time: 135.4s
# Epoch 134/150 | Loss: 9.99e-05 | MSE: 9.99e-05 | Terms: [] | Data: [obs: 9.99e-05] | Error: N/A | Params: [mu: 0.021997] | Time: 136.0s
# Epoch 135/150 | Loss: 9.98e-05 | MSE: 9.98e-05 | Terms: [] | Data: [obs: 9.98e-05] | Error: N/A | Params: [mu: 0.0219975] | Time: 136.7s
# Epoch 136/150 | Loss: 1.00e-04 | MSE: 1.00e-04 | Terms: [] | Data: [obs: 1.00e-04] | Error: N/A | Params: [mu: 0.0220049] | Time: 137.4s
# Epoch 137/150 | Loss: 9.94e-05 | MSE: 9.94e-05 | Terms: [] | Data: [obs: 9.94e-05] | Error: N/A | Params: [mu: 0.022003] | Time: 138.1s
# Epoch 138/150 | Loss: 1.00e-04 | MSE: 1.00e-04 | Terms: [] | Data: [obs: 1.00e-04] | Error: N/A | Params: [mu: 0.0219967] | Time: 138.7s
# Epoch 139/150 | Loss: 9.92e-05 | MSE: 9.92e-05 | Terms: [] | Data: [obs: 9.92e-05] | Error: N/A | Params: [mu: 0.0219998] | Time: 139.6s
# Epoch 140/150 | Loss: 1.00e-04 | MSE: 1.00e-04 | Terms: [] | Data: [obs: 1.00e-04] | Error: N/A | Params: [mu: 0.0220049] | Time: 140.2s
# Epoch 141/150 | Loss: 9.91e-05 | MSE: 9.91e-05 | Terms: [] | Data: [obs: 9.91e-05] | Error: N/A | Params: [mu: 0.0220007] | Time: 140.9s
# Epoch 142/150 | Loss: 9.99e-05 | MSE: 9.99e-05 | Terms: [] | Data: [obs: 9.99e-05] | Error: N/A | Params: [mu: 0.0219972] | Time: 141.6s
# Epoch 143/150 | Loss: 9.92e-05 | MSE: 9.92e-05 | Terms: [] | Data: [obs: 9.92e-05] | Error: N/A | Params: [mu: 0.0220019] | Time: 142.3s
# Epoch 144/150 | Loss: 9.96e-05 | MSE: 9.96e-05 | Terms: [] | Data: [obs: 9.96e-05] | Error: N/A | Params: [mu: 0.0220039] | Time: 143.0s
# Epoch 145/150 | Loss: 9.93e-05 | MSE: 9.93e-05 | Terms: [] | Data: [obs: 9.93e-05] | Error: N/A | Params: [mu: 0.021999] | Time: 143.6s
# Epoch 146/150 | Loss: 9.94e-05 | MSE: 9.94e-05 | Terms: [] | Data: [obs: 9.94e-05] | Error: N/A | Params: [mu: 0.0219986] | Time: 144.5s
# Epoch 147/150 | Loss: 9.95e-05 | MSE: 9.95e-05 | Terms: [] | Data: [obs: 9.95e-05] | Error: N/A | Params: [mu: 0.0220033] | Time: 145.2s
# Epoch 148/150 | Loss: 9.92e-05 | MSE: 9.92e-05 | Terms: [] | Data: [obs: 9.92e-05] | Error: N/A | Params: [mu: 0.022002] | Time: 145.8s
# Epoch 149/150 | Loss: 9.95e-05 | MSE: 9.95e-05 | Terms: [] | Data: [obs: 9.95e-05] | Error: N/A | Params: [mu: 0.0219982] | Time: 146.5s
# Epoch 150/150 | Loss: 9.91e-05 | MSE: 9.91e-05 | Terms: [] | Data: [obs: 9.91e-05] | Error: N/A | Params: [mu: 0.0220008] | Time: 147.2s
# Training complete in 147.8s
