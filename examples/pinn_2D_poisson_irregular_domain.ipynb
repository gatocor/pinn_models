# %% [markdown]
# # Transient heat equation on a U-shaped domain — AlphaPINN spectral PINN
#
# **PDE:**  $\partial_t u - \kappa\,\Delta u = 0$  (heat / diffusion)
#
# **Domain:**  $[0,2]\times[0,2]$ minus a notch $(x\in(0.6,1.4),\; y>0.8)$,  time $t\in[0,T]$
#
# **Initial condition:**  $u(x,y,0) = 0$
#
# **Boundary conditions:**
# - $u = 1$ on the **left-arm top** ($y=2,\; x\in[0,0.6]$) — hot, held for all $t$
# - $u = 0$ everywhere else on the boundary — cold, held for all $t$
#
# **Method:**  **AlphaPINN — global spectral PINN without Method of Lines.**
#
# Since the Laplace eigenvectors $\Phi$ are global spatial modes, the full
# space-time solution can be written as:
#
# $$u(x,t) = \Phi\,\alpha(t), \quad \alpha(t) = \text{FNN}(t) \in \mathbb{R}^K$$
#
# The FNN takes only $t$ as input and outputs the spectral expansion coefficients.
# Time derivatives follow by autodiff; no state, no rollout, no BPTT.
#
# Physics is enforced through the Galerkin weak-form residual:
#
# $$\int_\Omega \phi\,\partial_t u\,d\Omega + \kappa\int_\Omega \nabla u\cdot\nabla\phi\,d\Omega = 0 \quad \forall\,\phi\in V_h, \; t\in[0,T]$$
#
# The IC $u(\cdot,0)=0$ is added as a Dirichlet BC on the $t=0$ face of the domain.

# %% [markdown]
# ## 1. Imports & environment

# %%
import pinns
import jax.numpy as jnp
import numpy as np

import scipy.sparse as sp
import scipy.sparse.linalg as spla
from scipy.interpolate import RegularGridInterpolator
from scipy.ndimage import distance_transform_edt

X_MAX = 2
Y_MAX = 2
KAPPA = 1

# %% [markdown]
# ## 2. Build the U-shaped triangulated mesh

# %%
mesh = pinns.meshes.trident(mesh_size=0.03)

domain = pinns.domain.DomainMesh(mesh)

domain.add_boundary(lambda X: (X[:, 0] < 0.01), "symmetry")
domain.add_boundary(lambda X: (X[:, 1] < 0.01), "dirichlet")
domain.add_boundary(lambda X: ~((X[:, 0] < 0.01) | (X[:, 1] < 0.01)) | (X[:, 0] + X[:, 1] > 0.99), "convection")

domain.plot(boundary="custom", backend="matplotlib")
# Out:
# <Axes: title={'center': 'spatial'}, xlabel='x', ylabel='y'>

# %% [markdown]
# ## 6. PDE problem & AlphaPINN network
#
# $$\int_\Omega \phi\,\partial_t u\,d\Omega + \kappa\int_\Omega \nabla u\cdot\nabla\phi\,d\Omega = 0$$
#
# **Design:**  `ProblemWeak` is always defined **before** the network — it owns
# the `output_transform` that enforces Dirichlet BCs and the IC ramp at every query point.
# The network receives it as a constructor argument:
#
# ```python
# problem = ProblemWeak(..., hard_constraints=["bc_name", ...])
# net     = Network(domain, ..., output_transform=problem.output_transform)
# ```
#
# This pattern is **identical** for continuous and state-integrator modes, and for
# both `AlphaPINN` and `GNNMeshNetwork`.  In state-integrator mode the network also
# clamps BC nodes internally before storing $u^{n+1}$ as the next $u^n$ (keeps rollout
# stable), but that happens automatically — no extra argument required.
#
# `AlphaPINN` is literally `LaplacianFeatures(domain, n_features) + FNN(hidden_dims)`:
#
# | Component | Role |
# |---|---|
# | `LaplacianFeatures` | Maps `(x,y,t)` → `[Φ(x,y), t]` via barycentric interp of mesh eigenvectors |
# | `FNN(hidden_dims)` | Standard MLP: `n_features` → `hidden_dims` → `n_outputs` |
#
# No `n_time_steps`, no BPTT.  $\partial_t u$ comes from autodiff through the FNN w.r.t. the appended $t$ feature.

# %%
def volume_fn(x, y, params, phi, derivative=None):
    """Steady-state Poisson weak form: κ ∫ ∇u·∇φ dΩ = 0"""
    du_dx = derivative(y, x, 0, (0,))
    du_dy = derivative(y, x, 0, (1,))
    grad_u = jnp.stack([du_dx, du_dy], axis=-1)

    dphi_dx = derivative(phi, x, 0, (0,))
    dphi_dy = derivative(phi, x, 0, (1,))
    grad_phi = jnp.stack([dphi_dx, dphi_dy], axis=-1)

    return jnp.sum(grad_u * grad_phi, axis=-1)

problem = pinns.ProblemWeak(domain=domain, output_names=["temperature"])

problem.add_inner(volume_fn, name="pde", region="inner")

problem.add_dirichlet(1.0, name="dirichlet",  region="dirichlet")
problem.add_neumann(0.0, name="symmetry",   region="symmetry")
def convection_fn(x, u, params, phi, derivative=None):
    # u has shape (N, n_out); extract scalar component 0 before multiplying with phi (N,)
    return -0.1 * u[..., 0] * phi
problem.add_neumann(convection_fn, name="convection", region="convection")

problem.add_parameter("kappa", KAPPA)
# Out:
# ProblemWeak(n_verts=1303, n_dofs=1303, n_faces=2266, n_free=1303, n_dirichlet=0, n_neumann_bcs=0, cubature_order=3, lagrange_order=1 (P1, 3 dofs/elem), basis='lagrange')

# %%
model = pinns.create_model(
    domain,
    output_dim=1,
    features=pinns.LaplacianFeatures(n_features=256),
)
# Out:
# LaplacianFeatures: computing 257 Laplace eigenvectors for mesh with 1303 nodes (dropping constant mode 0) … done.

# %% [markdown]
# ## 7. Training
#
# Standard PINN training — no curriculum, no BPTT.  The full space-time loss:
#
# $$\mathcal{L}(\theta) = \|\mathcal{R}(u_\theta)\|^2 + \lambda_\text{BC}\|\text{BCs}\|^2 + \lambda_\text{IC}\|u_\theta(\cdot,0)\|^2$$
#
# is minimised in one shot.

# %%
trainer = pinns.Trainer(model, problem=problem)

trainer.compile(
    problem={
        "pde" :      {"train": 1000, "test": 50, "weight": 1.0},
        "dirichlet": {"train": 200,  "test": 10,  "weight": 1.0},
        "symmetry":  {"train": 200,  "test": 10,  "weight": 1.0},
        "convection":{"train": 1000,  "test": 10,  "weight": 1.0}
    },
    optimizer=pinns.SOAPOptimizer(),
    schedulers=[
        pinns.SchedulerLagrange(
            ["convection","symmetry","dirichlet"]
        )
    ],
    epochs=100000,
    print_each=1000,
)

trainer.train()
# Out:
# Starting training for 100000 epochs (JIT-compiled)...
# Epoch 0/100000 | Loss: 1.89e+04 | MSE: 9.46e+03 | Terms: [convection: 4.35e+00, dirichlet: 1.33e+00, pde: 9.45e+03, symmetry: 4.49e+00] | Test Loss: 1.89e+04 | Time: 0.0s
# Epoch 1000/100000 | Loss: 2.58e-02 | MSE: 3.42e-02 | Terms: [convection: 2.68e-03, dirichlet: 4.55e-03, pde: 2.68e-02, symmetry: 1.19e-04] | Test Loss: 7.34e-02 | Time: 21.4s
# Epoch 2000/100000 | Loss: 1.53e-02 | MSE: 1.90e-02 | Terms: [convection: 1.57e-03, dirichlet: 1.77e-03, pde: 1.56e-02, symmetry: 2.51e-05] | Test Loss: 3.79e-02 | Time: 24.0s
# Epoch 3000/100000 | Loss: 9.08e-03 | MSE: 1.07e-02 | Terms: [convection: 1.55e-03, dirichlet: 7.27e-04, pde: 8.35e-03, symmetry: 2.27e-05] | Test Loss: 2.20e-02 | Time: 26.3s
# Epoch 4000/100000 | Loss: 4.52e-03 | MSE: 5.18e-03 | Terms: [convection: 1.70e-03, dirichlet: 2.88e-04, pde: 3.17e-03, symmetry: 1.82e-05] | Test Loss: 1.12e-02 | Time: 28.7s
# Epoch 5000/100000 | Loss: 2.94e-03 | MSE: 3.22e-03 | Terms: [convection: 1.88e-03, dirichlet: 1.08e-04, pde: 1.22e-03, symmetry: 1.90e-05] | Test Loss: 6.52e-03 | Time: 31.0s
# Epoch 6000/100000 | Loss: 2.26e-03 | MSE: 2.39e-03 | Terms: [convection: 1.99e-03, dirichlet: 4.03e-05, pde: 3.38e-04, symmetry: 2.15e-05] | Test Loss: 4.75e-03 | Time: 33.3s
# Epoch 7000/100000 | Loss: 1.99e-03 | MSE: 2.08e-03 | Terms: [convection: 1.78e-03, dirichlet: 4.02e-05, pde: 2.43e-04, symmetry: 1.84e-05] | Test Loss: 4.19e-03 | Time: 35.7s
# Epoch 8000/100000 | Loss: 2.08e-03 | MSE: 2.14e-03 | Terms: [convection: 1.63e-03, dirichlet: 3.04e-05, pde: 4.57e-04, symmetry: 1.53e-05] | Test Loss: 4.25e-03 | Time: 38.1s
# Epoch 9000/100000 | Loss: 1.96e-03 | MSE: 1.99e-03 | Terms: [convection: 1.48e-03, dirichlet: 2.27e-05, pde: 4.80e-04, symmetry: 1.27e-05] | Test Loss: 3.90e-03 | Time: 40.4s
# Epoch 10000/100000 | Loss: 1.63e-03 | MSE: 1.65e-03 | Terms: [convection: 1.33e-03, dirichlet: 1.77e-05, pde: 2.87e-04, symmetry: 1.15e-05] | Test Loss: 3.37e-03 | Time: 42.8s
# Epoch 11000/100000 | Loss: 1.75e-03 | MSE: 1.76e-03 | Terms: [convection: 1.19e-03, dirichlet: 1.52e-05, pde: 5.44e-04, symmetry: 9.70e-06] | Test Loss: 3.56e-03 | Time: 45.1s
# Epoch 12000/100000 | Loss: 1.43e-03 | MSE: 1.42e-03 | Terms: [convection: 1.04e-03, dirichlet: 1.22e-05, pde: 3.52e-04, symmetry: 8.79e-06] | Test Loss: 2.84e-03 | Time: 47.4s
# Epoch 13000/100000 | Loss: 1.40e-03 | MSE: 1.39e-03 | Terms: [convection: 8.98e-04, dirichlet: 9.43e-06, pde: 4.73e-04, symmetry: 7.22e-06] | Test Loss: 2.71e-03 | Time: 49.8s
# Epoch 14000/100000 | Loss: 1.34e-03 | MSE: 1.32e-03 | Terms: [convection: 7.75e-04, dirichlet: 6.99e-06, pde: 5.35e-04, symmetry: 5.17e-06] | Test Loss: 2.66e-03 | Time: 52.1s
# Epoch 15000/100000 | Loss: 1.22e-03 | MSE: 1.20e-03 | Terms: [convection: 6.71e-04, dirichlet: 5.94e-06, pde: 5.24e-04, symmetry: 3.88e-06] | Test Loss: 2.37e-03 | Time: 54.4s
# Epoch 16000/100000 | Loss: 1.12e-03 | MSE: 1.10e-03 | Terms: [convection: 5.84e-04, dirichlet: 5.68e-06, pde: 5.04e-04, symmetry: 3.64e-06] | Test Loss: 2.24e-03 | Time: 56.8s
# Epoch 17000/100000 | Loss: 1.09e-03 | MSE: 1.07e-03 | Terms: [convection: 5.16e-04, dirichlet: 5.78e-06, pde: 5.42e-04, symmetry: 2.93e-06] | Test Loss: 2.12e-03 | Time: 59.1s
# Epoch 18000/100000 | Loss: 1.12e-03 | MSE: 1.10e-03 | Terms: [convection: 4.37e-04, dirichlet: 5.95e-06, pde: 6.53e-04, symmetry: 2.31e-06] | Test Loss: 2.06e-03 | Time: 61.5s
# Epoch 19000/100000 | Loss: 9.30e-04 | MSE: 9.00e-04 | Terms: [convection: 3.93e-04, dirichlet: 5.46e-06, pde: 4.99e-04, symmetry: 1.92e-06] | Test Loss: 1.80e-03 | Time: 63.9s
# Epoch 20000/100000 | Loss: 8.21e-04 | MSE: 7.85e-04 | Terms: [convection: 3.40e-04, dirichlet: 5.05e-06, pde: 4.39e-04, symmetry: 1.04e-06] | Test Loss: 1.64e-03 | Time: 66.2s
# Epoch 21000/100000 | Loss: 8.86e-04 | MSE: 8.47e-04 | Terms: [convection: 3.11e-04, dirichlet: 4.38e-06, pde: 5.31e-04, symmetry: 5.85e-07] | Test Loss: 1.63e-03 | Time: 68.6s
# Epoch 22000/100000 | Loss: 8.07e-04 | MSE: 7.67e-04 | Terms: [convection: 2.80e-04, dirichlet: 3.84e-06, pde: 4.81e-04, symmetry: 9.30e-07] | Test Loss: 1.49e-03 | Time: 70.9s
# Epoch 23000/100000 | Loss: 7.56e-04 | MSE: 7.14e-04 | Terms: [convection: 2.58e-04, dirichlet: 3.33e-06, pde: 4.52e-04, symmetry: 8.47e-07] | Test Loss: 1.48e-03 | Time: 73.2s
# Epoch 24000/100000 | Loss: 7.12e-04 | MSE: 6.69e-04 | Terms: [convection: 2.25e-04, dirichlet: 3.16e-06, pde: 4.39e-04, symmetry: 5.77e-07] | Test Loss: 1.33e-03 | Time: 75.6s
# Epoch 25000/100000 | Loss: 6.60e-04 | MSE: 6.16e-04 | Terms: [convection: 2.10e-04, dirichlet: 2.97e-06, pde: 4.03e-04, symmetry: 8.30e-07] | Test Loss: 1.28e-03 | Time: 77.9s
# Epoch 26000/100000 | Loss: 6.91e-04 | MSE: 6.48e-04 | Terms: [convection: 1.81e-04, dirichlet: 3.12e-06, pde: 4.64e-04, symmetry: 2.60e-07] | Test Loss: 1.30e-03 | Time: 80.2s
# Epoch 27000/100000 | Loss: 6.63e-04 | MSE: 6.21e-04 | Terms: [convection: 1.73e-04, dirichlet: 2.88e-06, pde: 4.44e-04, symmetry: 6.40e-07] | Test Loss: 1.24e-03 | Time: 82.6s
# Epoch 28000/100000 | Loss: 5.95e-04 | MSE: 5.54e-04 | Terms: [convection: 1.55e-04, dirichlet: 2.83e-06, pde: 3.96e-04, symmetry: 1.82e-07] | Test Loss: 1.07e-03 | Time: 84.9s
# Epoch 29000/100000 | Loss: 5.54e-04 | MSE: 5.15e-04 | Terms: [convection: 1.40e-04, dirichlet: 2.76e-06, pde: 3.72e-04, symmetry: 4.46e-07] | Test Loss: 1.02e-03 | Time: 87.3s
# Epoch 30000/100000 | Loss: 5.01e-04 | MSE: 4.65e-04 | Terms: [convection: 1.26e-04, dirichlet: 2.48e-06, pde: 3.36e-04, symmetry: 2.51e-07] | Test Loss: 8.86e-04 | Time: 89.7s
# Epoch 31000/100000 | Loss: 4.81e-04 | MSE: 4.52e-04 | Terms: [convection: 1.22e-04, dirichlet: 2.29e-06, pde: 3.27e-04, symmetry: 3.96e-07] | Test Loss: 9.05e-04 | Time: 92.0s
# Epoch 32000/100000 | Loss: 4.39e-04 | MSE: 4.19e-04 | Terms: [convection: 1.11e-04, dirichlet: 2.23e-06, pde: 3.06e-04, symmetry: 3.81e-07] | Test Loss: 8.18e-04 | Time: 94.4s
# Epoch 33000/100000 | Loss: 3.77e-04 | MSE: 3.71e-04 | Terms: [convection: 9.65e-05, dirichlet: 2.56e-06, pde: 2.71e-04, symmetry: 5.26e-07] | Test Loss: 8.10e-04 | Time: 96.7s
# Epoch 34000/100000 | Loss: 3.78e-04 | MSE: 3.90e-04 | Terms: [convection: 9.83e-05, dirichlet: 3.44e-06, pde: 2.88e-04, symmetry: 3.27e-07] | Test Loss: 7.67e-04 | Time: 99.1s
# Epoch 35000/100000 | Loss: 3.60e-04 | MSE: 3.92e-04 | Terms: [convection: 8.82e-05, dirichlet: 5.37e-06, pde: 2.98e-04, symmetry: 1.70e-07] | Test Loss: 7.87e-04 | Time: 101.4s
# Epoch 36000/100000 | Loss: 3.52e-04 | MSE: 4.05e-04 | Terms: [convection: 8.34e-05, dirichlet: 7.94e-06, pde: 3.13e-04, symmetry: 3.39e-07] | Test Loss: 8.43e-04 | Time: 103.8s
# Epoch 37000/100000 | Loss: 3.12e-04 | MSE: 3.82e-04 | Terms: [convection: 7.83e-05, dirichlet: 1.07e-05, pde: 2.93e-04, symmetry: 3.98e-07] | Test Loss: 7.39e-04 | Time: 106.1s
# Epoch 38000/100000 | Loss: 3.18e-04 | MSE: 3.99e-04 | Terms: [convection: 7.45e-05, dirichlet: 1.38e-05, pde: 3.10e-04, symmetry: 5.68e-07] | Test Loss: 7.92e-04 | Time: 108.4s
# Epoch 39000/100000 | Loss: 2.85e-04 | MSE: 3.68e-04 | Terms: [convection: 6.88e-05, dirichlet: 1.62e-05, pde: 2.82e-04, symmetry: 2.88e-07] | Test Loss: 6.71e-04 | Time: 110.9s
# Epoch 40000/100000 | Loss: 2.89e-04 | MSE: 3.64e-04 | Terms: [convection: 7.07e-05, dirichlet: 1.73e-05, pde: 2.75e-04, symmetry: 1.05e-06] | Test Loss: 7.04e-04 | Time: 113.2s
# Epoch 41000/100000 | Loss: 2.46e-04 | MSE: 3.08e-04 | Terms: [convection: 6.75e-05, dirichlet: 1.67e-05, pde: 2.24e-04, symmetry: 4.74e-07] | Test Loss: 6.16e-04 | Time: 115.6s
# Epoch 42000/100000 | Loss: 2.84e-04 | MSE: 3.29e-04 | Terms: [convection: 6.15e-05, dirichlet: 1.47e-05, pde: 2.52e-04, symmetry: 1.11e-06] | Test Loss: 6.24e-04 | Time: 117.9s
# Epoch 43000/100000 | Loss: 3.24e-04 | MSE: 3.54e-04 | Terms: [convection: 5.84e-05, dirichlet: 1.05e-05, pde: 2.85e-04, symmetry: 2.54e-07] | Test Loss: 7.00e-04 | Time: 120.3s
# Epoch 44000/100000 | Loss: 2.69e-04 | MSE: 2.88e-04 | Terms: [convection: 5.52e-05, dirichlet: 6.63e-06, pde: 2.26e-04, symmetry: 5.46e-07] | Test Loss: 5.39e-04 | Time: 122.6s
# Epoch 45000/100000 | Loss: 2.62e-04 | MSE: 2.75e-04 | Terms: [convection: 5.20e-05, dirichlet: 4.20e-06, pde: 2.19e-04, symmetry: 2.78e-07] | Test Loss: 5.44e-04 | Time: 124.9s
# Epoch 46000/100000 | Loss: 2.65e-04 | MSE: 2.75e-04 | Terms: [convection: 4.87e-05, dirichlet: 2.65e-06, pde: 2.23e-04, symmetry: 6.44e-07] | Test Loss: 5.43e-04 | Time: 127.3s
# Epoch 47000/100000 | Loss: 2.25e-04 | MSE: 2.34e-04 | Terms: [convection: 4.77e-05, dirichlet: 1.94e-06, pde: 1.82e-04, symmetry: 1.75e-06] | Test Loss: 4.42e-04 | Time: 129.6s
# Epoch 48000/100000 | Loss: 2.17e-04 | MSE: 2.25e-04 | Terms: [convection: 4.47e-05, dirichlet: 1.61e-06, pde: 1.79e-04, symmetry: 2.70e-07] | Test Loss: 4.63e-04 | Time: 131.9s
# Epoch 49000/100000 | Loss: 2.27e-04 | MSE: 2.35e-04 | Terms: [convection: 4.09e-05, dirichlet: 1.45e-06, pde: 1.93e-04, symmetry: 2.46e-07] | Test Loss: 4.42e-04 | Time: 134.4s
# Epoch 50000/100000 | Loss: 1.89e-04 | MSE: 1.98e-04 | Terms: [convection: 3.92e-05, dirichlet: 1.53e-06, pde: 1.56e-04, symmetry: 8.88e-07] | Test Loss: 4.44e-04 | Time: 136.7s
# Epoch 51000/100000 | Loss: 1.96e-04 | MSE: 2.04e-04 | Terms: [convection: 3.80e-05, dirichlet: 1.26e-06, pde: 1.64e-04, symmetry: 9.88e-07] | Test Loss: 4.10e-04 | Time: 139.1s
# Epoch 52000/100000 | Loss: 1.97e-04 | MSE: 2.04e-04 | Terms: [convection: 3.61e-05, dirichlet: 1.47e-06, pde: 1.67e-04, symmetry: 2.64e-07] | Test Loss: 4.14e-04 | Time: 141.4s
# Epoch 53000/100000 | Loss: 1.84e-04 | MSE: 1.91e-04 | Terms: [convection: 3.38e-05, dirichlet: 1.28e-06, pde: 1.55e-04, symmetry: 1.60e-06] | Test Loss: 4.02e-04 | Time: 143.7s
# Epoch 54000/100000 | Loss: 2.11e-04 | MSE: 2.18e-04 | Terms: [convection: 3.27e-05, dirichlet: 1.23e-06, pde: 1.84e-04, symmetry: 1.64e-07] | Test Loss: 4.28e-04 | Time: 146.1s
# Epoch 55000/100000 | Loss: 1.56e-04 | MSE: 1.62e-04 | Terms: [convection: 3.03e-05, dirichlet: 1.19e-06, pde: 1.31e-04, symmetry: 1.46e-07] | Test Loss: 3.41e-04 | Time: 148.4s
# Epoch 56000/100000 | Loss: 1.64e-04 | MSE: 1.70e-04 | Terms: [convection: 2.92e-05, dirichlet: 1.29e-06, pde: 1.39e-04, symmetry: 1.52e-07] | Test Loss: 3.60e-04 | Time: 150.7s
# Epoch 57000/100000 | Loss: 1.70e-04 | MSE: 1.75e-04 | Terms: [convection: 2.72e-05, dirichlet: 9.24e-07, pde: 1.47e-04, symmetry: 2.69e-07] | Test Loss: 3.52e-04 | Time: 153.1s
# Epoch 58000/100000 | Loss: 1.41e-04 | MSE: 1.46e-04 | Terms: [convection: 2.54e-05, dirichlet: 8.47e-07, pde: 1.19e-04, symmetry: 1.67e-07] | Test Loss: 3.20e-04 | Time: 155.4s
# Epoch 59000/100000 | Loss: 1.41e-04 | MSE: 1.46e-04 | Terms: [convection: 2.52e-05, dirichlet: 6.99e-07, pde: 1.20e-04, symmetry: 8.47e-08] | Test Loss: 2.96e-04 | Time: 157.9s
# Epoch 60000/100000 | Loss: 1.49e-04 | MSE: 1.54e-04 | Terms: [convection: 2.26e-05, dirichlet: 6.22e-07, pde: 1.30e-04, symmetry: 8.25e-07] | Test Loss: 2.91e-04 | Time: 160.2s
# Epoch 61000/100000 | Loss: 1.30e-04 | MSE: 1.34e-04 | Terms: [convection: 2.24e-05, dirichlet: 5.73e-07, pde: 1.11e-04, symmetry: 5.00e-07] | Test Loss: 2.62e-04 | Time: 162.6s
# Epoch 62000/100000 | Loss: 1.44e-04 | MSE: 1.48e-04 | Terms: [convection: 2.09e-05, dirichlet: 4.56e-07, pde: 1.26e-04, symmetry: 3.89e-07] | Test Loss: 2.91e-04 | Time: 164.9s
# Epoch 63000/100000 | Loss: 1.38e-04 | MSE: 1.43e-04 | Terms: [convection: 1.90e-05, dirichlet: 4.90e-07, pde: 1.23e-04, symmetry: 5.94e-08] | Test Loss: 2.83e-04 | Time: 167.2s
# Epoch 64000/100000 | Loss: 1.41e-04 | MSE: 1.45e-04 | Terms: [convection: 1.90e-05, dirichlet: 6.12e-07, pde: 1.26e-04, symmetry: 4.11e-08] | Test Loss: 2.94e-04 | Time: 169.6s
# Epoch 65000/100000 | Loss: 1.43e-04 | MSE: 1.48e-04 | Terms: [convection: 1.79e-05, dirichlet: 4.03e-07, pde: 1.29e-04, symmetry: 1.31e-07] | Test Loss: 2.85e-04 | Time: 171.9s
# Epoch 66000/100000 | Loss: 1.42e-04 | MSE: 1.46e-04 | Terms: [convection: 1.73e-05, dirichlet: 3.84e-07, pde: 1.28e-04, symmetry: 8.15e-08] | Test Loss: 2.90e-04 | Time: 174.3s
# Epoch 67000/100000 | Loss: 1.12e-04 | MSE: 1.16e-04 | Terms: [convection: 1.56e-05, dirichlet: 3.95e-07, pde: 9.93e-05, symmetry: 5.32e-07] | Test Loss: 2.41e-04 | Time: 176.6s
# Epoch 68000/100000 | Loss: 1.11e-04 | MSE: 1.15e-04 | Terms: [convection: 1.54e-05, dirichlet: 3.86e-07, pde: 9.94e-05, symmetry: 7.92e-08] | Test Loss: 2.32e-04 | Time: 178.9s
# Epoch 69000/100000 | Loss: 1.20e-04 | MSE: 1.24e-04 | Terms: [convection: 1.41e-05, dirichlet: 3.82e-07, pde: 1.09e-04, symmetry: 4.86e-08] | Test Loss: 2.46e-04 | Time: 181.3s
# Epoch 70000/100000 | Loss: 1.20e-04 | MSE: 1.24e-04 | Terms: [convection: 1.36e-05, dirichlet: 4.64e-07, pde: 1.10e-04, symmetry: 1.12e-07] | Test Loss: 2.46e-04 | Time: 183.8s
# Epoch 71000/100000 | Loss: 1.06e-04 | MSE: 1.09e-04 | Terms: [convection: 1.23e-05, dirichlet: 4.00e-07, pde: 9.63e-05, symmetry: 1.31e-07] | Test Loss: 2.13e-04 | Time: 186.1s
# Epoch 72000/100000 | Loss: 1.03e-04 | MSE: 1.07e-04 | Terms: [convection: 1.24e-05, dirichlet: 5.80e-07, pde: 9.35e-05, symmetry: 1.59e-07] | Test Loss: 1.95e-04 | Time: 188.5s
# Epoch 73000/100000 | Loss: 1.01e-04 | MSE: 1.04e-04 | Terms: [convection: 1.18e-05, dirichlet: 4.28e-07, pde: 9.18e-05, symmetry: 1.19e-07] | Test Loss: 2.10e-04 | Time: 190.8s
# Epoch 74000/100000 | Loss: 7.94e-05 | MSE: 8.23e-05 | Terms: [convection: 1.05e-05, dirichlet: 3.42e-07, pde: 7.14e-05, symmetry: 6.13e-08] | Test Loss: 1.71e-04 | Time: 193.1s
# Epoch 75000/100000 | Loss: 9.99e-05 | MSE: 1.03e-04 | Terms: [convection: 1.04e-05, dirichlet: 3.31e-07, pde: 9.17e-05, symmetry: 7.88e-08] | Test Loss: 2.06e-04 | Time: 195.5s
# Epoch 76000/100000 | Loss: 1.02e-04 | MSE: 1.04e-04 | Terms: [convection: 9.68e-06, dirichlet: 3.41e-07, pde: 9.39e-05, symmetry: 5.50e-08] | Test Loss: 2.04e-04 | Time: 197.8s
# Epoch 77000/100000 | Loss: 1.06e-04 | MSE: 1.08e-04 | Terms: [convection: 9.41e-06, dirichlet: 3.09e-07, pde: 9.75e-05, symmetry: 1.05e-06] | Test Loss: 2.02e-04 | Time: 200.2s
# Epoch 78000/100000 | Loss: 8.95e-05 | MSE: 9.16e-05 | Terms: [convection: 9.20e-06, dirichlet: 3.28e-07, pde: 8.20e-05, symmetry: 3.61e-08] | Test Loss: 2.02e-04 | Time: 202.5s
# Epoch 79000/100000 | Loss: 8.53e-05 | MSE: 8.71e-05 | Terms: [convection: 8.50e-06, dirichlet: 2.97e-07, pde: 7.83e-05, symmetry: 2.07e-08] | Test Loss: 1.80e-04 | Time: 204.9s
# Epoch 80000/100000 | Loss: 9.56e-05 | MSE: 9.74e-05 | Terms: [convection: 7.69e-06, dirichlet: 4.30e-07, pde: 8.92e-05, symmetry: 5.44e-08] | Test Loss: 1.89e-04 | Time: 207.3s
# Epoch 81000/100000 | Loss: 9.53e-05 | MSE: 9.69e-05 | Terms: [convection: 7.69e-06, dirichlet: 2.75e-07, pde: 8.86e-05, symmetry: 3.02e-07] | Test Loss: 1.96e-04 | Time: 209.7s
# Epoch 82000/100000 | Loss: 8.89e-05 | MSE: 9.05e-05 | Terms: [convection: 7.16e-06, dirichlet: 3.70e-07, pde: 8.29e-05, symmetry: 4.93e-08] | Test Loss: 1.78e-04 | Time: 212.0s
# Epoch 83000/100000 | Loss: 8.97e-05 | MSE: 9.11e-05 | Terms: [convection: 6.70e-06, dirichlet: 3.03e-07, pde: 8.40e-05, symmetry: 1.32e-07] | Test Loss: 1.73e-04 | Time: 214.4s
# Epoch 84000/100000 | Loss: 8.68e-05 | MSE: 8.81e-05 | Terms: [convection: 6.55e-06, dirichlet: 2.25e-07, pde: 8.09e-05, symmetry: 4.37e-07] | Test Loss: 1.75e-04 | Time: 216.7s
# Epoch 85000/100000 | Loss: 8.10e-05 | MSE: 8.24e-05 | Terms: [convection: 6.45e-06, dirichlet: 1.80e-07, pde: 7.57e-05, symmetry: 6.54e-08] | Test Loss: 1.76e-04 | Time: 219.0s
# Epoch 86000/100000 | Loss: 8.13e-05 | MSE: 8.26e-05 | Terms: [convection: 6.43e-06, dirichlet: 1.61e-07, pde: 7.60e-05, symmetry: 5.13e-08] | Test Loss: 1.56e-04 | Time: 221.4s
# Epoch 87000/100000 | Loss: 8.18e-05 | MSE: 8.31e-05 | Terms: [convection: 5.39e-06, dirichlet: 1.52e-07, pde: 7.74e-05, symmetry: 1.10e-07] | Test Loss: 1.75e-04 | Time: 223.7s
# Epoch 88000/100000 | Loss: 8.00e-05 | MSE: 8.13e-05 | Terms: [convection: 5.35e-06, dirichlet: 1.35e-07, pde: 7.56e-05, symmetry: 2.76e-07] | Test Loss: 1.74e-04 | Time: 226.0s
# Epoch 89000/100000 | Loss: 7.70e-05 | MSE: 7.83e-05 | Terms: [convection: 4.89e-06, dirichlet: 1.38e-07, pde: 7.30e-05, symmetry: 2.14e-07] | Test Loss: 1.57e-04 | Time: 228.4s
# Epoch 90000/100000 | Loss: 7.56e-05 | MSE: 7.68e-05 | Terms: [convection: 4.66e-06, dirichlet: 1.18e-07, pde: 7.18e-05, symmetry: 2.62e-07] | Test Loss: 1.65e-04 | Time: 230.8s
# Epoch 91000/100000 | Loss: 6.29e-05 | MSE: 6.41e-05 | Terms: [convection: 4.93e-06, dirichlet: 1.58e-07, pde: 5.90e-05, symmetry: 4.90e-08] | Test Loss: 1.60e-04 | Time: 233.2s
# Epoch 92000/100000 | Loss: 6.92e-05 | MSE: 7.06e-05 | Terms: [convection: 4.27e-06, dirichlet: 2.92e-07, pde: 6.59e-05, symmetry: 6.76e-08] | Test Loss: 1.35e-04 | Time: 235.5s
# Epoch 93000/100000 | Loss: 7.28e-05 | MSE: 7.41e-05 | Terms: [convection: 4.35e-06, dirichlet: 1.59e-07, pde: 6.96e-05, symmetry: 2.57e-08] | Test Loss: 1.53e-04 | Time: 237.8s
# Epoch 94000/100000 | Loss: 7.39e-05 | MSE: 7.51e-05 | Terms: [convection: 4.40e-06, dirichlet: 9.86e-08, pde: 7.05e-05, symmetry: 1.01e-07] | Test Loss: 1.51e-04 | Time: 240.2s
# Epoch 95000/100000 | Loss: 7.00e-05 | MSE: 7.12e-05 | Terms: [convection: 4.01e-06, dirichlet: 1.77e-07, pde: 6.70e-05, symmetry: 2.80e-08] | Test Loss: 1.51e-04 | Time: 242.5s
# Epoch 96000/100000 | Loss: 6.98e-05 | MSE: 7.10e-05 | Terms: [convection: 3.45e-06, dirichlet: 1.96e-07, pde: 6.73e-05, symmetry: 3.51e-08] | Test Loss: 1.37e-04 | Time: 244.9s
# Epoch 97000/100000 | Loss: 7.25e-05 | MSE: 7.36e-05 | Terms: [convection: 3.43e-06, dirichlet: 2.01e-07, pde: 6.99e-05, symmetry: 5.06e-08] | Test Loss: 1.37e-04 | Time: 247.2s
# Epoch 98000/100000 | Loss: 6.76e-05 | MSE: 6.87e-05 | Terms: [convection: 3.48e-06, dirichlet: 3.43e-07, pde: 6.45e-05, symmetry: 3.90e-07] | Test Loss: 1.45e-04 | Time: 249.5s
# Epoch 99000/100000 | Loss: 7.53e-05 | MSE: 7.64e-05 | Terms: [convection: 3.28e-06, dirichlet: 2.35e-07, pde: 7.29e-05, symmetry: 3.40e-08] | Test Loss: 1.29e-04 | Time: 251.9s
# Epoch 100000/100000 | Loss: 7.48e-05 | MSE: 7.59e-05 | Terms: [convection: 2.93e-06, dirichlet: 9.11e-08, pde: 7.28e-05, symmetry: 4.82e-08] | Test Loss: 1.52e-04 | Time: 254.3s
# Training complete in 254.6s
