# %% [markdown]
# # 2D Grey–Scott Reaction–Diffusion Equation
#
# The Grey–Scott system models two interacting chemical species $u$ and $v$:
#
# $$u_t = \varepsilon_1\,\Delta u + b_1(1 - u) - c_1\,u\,v^2, \quad (x,y) \in (-1,1)^2,\;t \in (0,2)$$
# $$v_t = \varepsilon_2\,\Delta v - b_2\,v + c_2\,u\,v^2, \quad (x,y) \in (-1,1)^2,\;t \in (0,2)$$
#
# **Periodic boundary conditions** on both $x$ and $y$.
#
# **Initial conditions:**
# $$u_0(x,y) = 1 - e^{-10\left((x+0.05)^2+(y+0.02)^2\right)}$$
# $$v_0(x,y) = e^{-10\left((x-0.05)^2+(y-0.02)^2\right)}$$
#
# **Parameters:** $\varepsilon_1=0.2$, $\varepsilon_2=0.1$, $b_1=40$, $b_2=100$, $c_1=c_2=1000$.

# %%
import pinns

import numpy as np
import jax.numpy as jnp

# %% [markdown]
# ## Domain
#
# $(x,y) \in [-1,1]^2$, $t \in [0,2]$. Periodic BCs on both spatial axes.

# %%
domain = pinns.DomainCubic(
    space=[(-1.0, 1.0), (-1.0, 1.0)],  # (x_min, x_max), (y_min, y_max)
    time =np.linspace(0.0, 2.0, 11),   # 10 time partitions: [0, 0.2, 0.4, …, 2.0]
)

# %% [markdown]
# ## PDE Residuals
#
# Two coupled residuals, one per species. The network outputs $[u, v]$.
#
# $$\mathcal{R}_u = u_t - \varepsilon_1(u_{xx} + u_{yy}) - b_1(1-u) + c_1 u v^2 = 0$$
# $$\mathcal{R}_v = v_t - \varepsilon_2(v_{xx} + v_{yy}) + b_2 v - c_2 u v^2 = 0$$

# %%
import jax

problem = pinns.ProblemStrong(domain=domain, output_names=["u", "v"])

def grey_scott_residual(X, U, params, derivative=None):
    # X columns: 0=x, 1=y, 2=t
    p = params
    eps1 = p['eps1'];  eps2 = p['eps2']
    b1   = p['b1'];    b2   = p['b2']
    c1   = p['c1'];    c2   = p['c2']

    u = U[:, 0:1]
    v = U[:, 1:2]

    dt_all   = derivative.all(X, (2,))       # (N, 2): [u_t,  v_t ]
    dxx_all  = derivative.all(X, (0, 0))     # (N, 2): [u_xx, v_xx]
    dyy_all  = derivative.all(X, (1, 1))     # (N, 2): [u_yy, v_yy]

    u_t  = dt_all[:,  0:1];  v_t  = dt_all[:,  1:2]
    u_xx = dxx_all[:, 0:1];  v_xx = dxx_all[:, 1:2]
    u_yy = dyy_all[:, 0:1];  v_yy = dyy_all[:, 1:2]

    uv2 = u * v**2

    res_u = u_t - eps1 * (u_xx + u_yy) - b1 * (1.0 - u) + c1 * uv2
    res_v = v_t - eps2 * (v_xx + v_yy) + b2 * v          - c2 * uv2

    return jnp.concatenate([res_u, res_v], axis=1)   # (N, 2)

problem.add_inner(grey_scott_residual, name="pde")

def u_initial(X):
    x = X[:, 0:1]
    y = X[:, 1:2]
    u0 = 1.0 - jnp.exp(-10.0 * ((x + 0.05)**2 + (y + 0.02)**2))
    v0 =       jnp.exp(-10.0 * ((x - 0.05)**2 + (y - 0.02)**2))   
    return jnp.concatenate([u0, v0], axis=1)   # (N, 2)

problem.add_initial(u_initial, name="initial", outputs=["u", "v"])

problem.add_parameter("eps1", 0.2)

problem.add_parameter("eps2", 0.1)

problem.add_parameter("b1",   40.0)
problem.add_parameter("b2",   100.0)
problem.add_parameter("c1",   1000.0)
problem.add_parameter("c2",   1000.0)
# Out:
# ProblemStrong(domain=DomainCubic, n_dims=3, n_outputs=2, inner=1, boundary=0, initial=2, params=['eps1', 'eps2', 'b1', 'b2', 'c1', 'c2'], trainable=[])

# %% [markdown]
# ### Reference Solution (pseudo-spectral ETD2RK)
#
# Both species are evolved spectrally on a 2-D periodic grid using `ModelSolver` +
# `IntegratorETD2RK` (Cox–Matthews exponential time differencing).  In Fourier space:
#
# $$\partial_t \hat{u}_\mathbf{k} = \underbrace{-\varepsilon_1 |\mathbf{k}|^2 \hat{u}_\mathbf{k}}_{\text{linear (exact)}} + \underbrace{\widehat{b_1(1-u) - c_1 u v^2}}_{\text{nonlinear}}$$
#
# `IntegratorETD2RK` treats the stiff diffusion exactly via matrix exponentials
# (pointwise in Fourier space), avoiding the small-step restriction of explicit methods.

# %%
from scipy.interpolate import RegularGridInterpolator

# ── Parameters ────────────────────────────────────────────────────────────────
eps1_val = 0.2;    eps2_val = 0.1
b1_val   = 40.0;   b2_val   = 100.0
c1_val   = 1000.0; c2_val   = 1000.0

Nx = Ny = 128
Nt = 201        # saved snapshots (includes t=0)
T  = 2.0

t_ref = np.linspace(0.0, T, Nt)

# ── DomainCubic (geometry / sampling) ─────────────────────────────────────────
domain_gs = pinns.DomainCubic(
    space=[(-1.0, 1.0), (-1.0, 1.0)],
    time=(0.0, T),
)

# ── ModelSolver (2D periodic Fourier basis, shape=(Nx,Ny)) ───────────────────
#   Linear part:  L_u = -eps1*K², L_v = -eps2*K²  (exact in Fourier space)
#   Nonlinear:    N_u = b1*(1-u) - c1*u*v²,  N_v = -b2*v + c2*u*v²

integrator_gs = pinns.IntegratorETD2RK(dt=1e-4, checkpoint=False)

model_gs = pinns.ModelSolver(domain_gs, ["u", "v"], integrator_gs, shape=(Nx, Ny))

x_ref = np.array(model_gs._grids[0])   # (Nx,)
y_ref = np.array(model_gs._grids[1])   # (Ny,)

model_gs.set_linear_op(
    lambda K2, p: {
        "u": -p["eps1"] * K2,
        "v": -p["eps2"] * K2,
    }
)

def gs_nonlinear(state_hat, p):
    u   = model_gs.inverse(state_hat["u"])
    v   = model_gs.inverse(state_hat["v"])
    uv2 = u * v**2
    Nu  = p["b1"] * (1.0 - u) - p["c1"] * uv2
    Nv  = -p["b2"] * v        + p["c2"] * uv2
    return {
        "u": model_gs.forward(Nu),
        "v": model_gs.forward(Nv),
    }

model_gs.set_nonlinear_op(gs_nonlinear)
model_gs.add_parameter("eps1", eps1_val)
model_gs.add_parameter("eps2", eps2_val)
model_gs.add_parameter("b1",   b1_val)
model_gs.add_parameter("b2",   b2_val)
model_gs.add_parameter("c1",   c1_val)
model_gs.add_parameter("c2",   c2_val)

# ── Initial conditions ────────────────────────────────────────────────────────
XX, YY = np.meshgrid(x_ref, y_ref, indexing='ij')
u0 = jnp.array(1.0 - np.exp(-10.0 * ((XX + 0.05)**2 + (YY + 0.02)**2)))
v0 = jnp.array(      np.exp(-10.0 * ((XX - 0.05)**2 + (YY - 0.02)**2)))

model_gs.add_initial({"u": u0, "v": v0})

# ── Forward solve ─────────────────────────────────────────────────────────────
sol = model_gs.solve(t_obs=t_ref)
U_ref = np.array(sol["u"])   # (Nt, Nx, Ny)
V_ref = np.array(sol["v"])   # (Nt, Nx, Ny)

print(f"U_ref shape: {U_ref.shape}  range [{U_ref.min():.4f}, {U_ref.max():.4f}]")
print(f"V_ref shape: {V_ref.shape}  range [{V_ref.min():.4f}, {V_ref.max():.4f}]")

# ── Interpolants: X[:,0]=x, X[:,1]=y, X[:,2]=t → (N,2) ──────────────────────
_interp_u = RegularGridInterpolator(
    (x_ref, y_ref, t_ref),
    U_ref.transpose(1, 2, 0),   # (Nx, Ny, Nt)
    method='linear', bounds_error=False, fill_value=None,
)
_interp_v = RegularGridInterpolator(
    (x_ref, y_ref, t_ref),
    V_ref.transpose(1, 2, 0),
    method='linear', bounds_error=False, fill_value=None,
)

def uv_reference(X):
    """X[:,0]=x, X[:,1]=y, X[:,2]=t → (N,2)"""
    pts = np.asarray(X)[:, :3]
    return np.concatenate([
        _interp_u(pts)[:, None],
        _interp_v(pts)[:, None],
    ], axis=1)

import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].imshow(U_ref[-1], extent=(-1,1,-1,1), origin='lower', cmap='viridis')
axes[0].set_title(f"u at t={T}"); axes[0].set_xlabel("x"); axes[0].set_ylabel("y")
axes[1].imshow(V_ref[-1], extent=(-1,1,-1,1), origin='lower', cmap='magma')
axes[1].set_title(f"v at t={T}"); axes[1].set_xlabel("x"); axes[1].set_ylabel("y")
plt.tight_layout()
# Out:
# U_ref shape: (201, 128, 128)  range [0.0003, 1.0000]
# V_ref shape: (201, 128, 128)  range [-0.0015, 0.9997]

# %% [markdown]
# # Inverse Problem: Recovering all 6 Grey–Scott Parameters
#
# We treat all six parameters as unknown and recover them simultaneously.
#
# ## Scale issue
#
# The parameters span four orders of magnitude ($\varepsilon \sim 10^{-1}$, $b \sim 10^1$–$10^2$, $c \sim 10^3$).
# With a shared learning rate, Adam gradients for small parameters are swamped by large ones.
#
# **Solution — log-reparameterisation**: optimise $\ell_\theta = \log\theta$ instead of $\theta$.
# Each operator then reads `jnp.exp(p["log_eps1"])` etc.  Because the gradient of the loss w.r.t.
# $\ell_\theta$ is $\theta \cdot \partial \mathcal{L}/\partial\theta$, a unit step in log-space
# equals a *multiplicative* change — fully scale-invariant regardless of magnitude.
#
# $$\min_{\ell_{\varepsilon_1},\ell_{\varepsilon_2},\ell_{b_1},\ell_{b_2},\ell_{c_1},\ell_{c_2}} \;
# \frac{1}{N}\sum_i \Bigl(\bigl|u^{\text{pred}}_i - u^{\text{obs}}_i\bigr|^2
#                        +\bigl|v^{\text{pred}}_i - v^{\text{obs}}_i\bigr|^2\Bigr)$$
#
# | Parameter | True $\theta$ | Log initial guess |
# |-----------|--------------|-------------------|
# | $\varepsilon_1$ | 0.20 | $\log 0.14 \approx -1.97$ |
# | $\varepsilon_2$ | 0.10 | $\log 0.07 \approx -2.66$ |
# | $b_1$ | 40.0 | $\log 28 \approx 3.33$ |
# | $b_2$ | 100.0 | $\log 70 \approx 4.25$ |
# | $c_1$ | 1000.0 | $\log 700 \approx 6.55$ |
# | $c_2$ | 1000.0 | $\log 700 \approx 6.55$ |
#
# All log-parameters are now $\mathcal{O}(1)$–$\mathcal{O}(10)$ — a single learning rate works well.

# %%
# ── Noisy observations (1% Gaussian noise on both u and v) ───────────────────
rng_np  = np.random.default_rng(42)
U_noisy = U_ref + rng_np.normal(0, 0.01, U_ref.shape)
V_noisy = V_ref + rng_np.normal(0, 0.01, V_ref.shape)

# ── Inverse ModelSolver — log-reparameterised ─────────────────────────────────
# We optimise log(θ) instead of θ.  The operators call jnp.exp(p["log_*"]) to
# recover the physical parameter.  This makes all optimised variables O(1-10)
# regardless of the original magnitude, so a single learning rate works for all.

integrator_inv = pinns.IntegratorETD2RK(dt=1e-4, checkpoint=True)
model_inv = pinns.ModelSolver(domain_gs, ["u", "v"], integrator_inv, shape=(Nx, Ny))

model_inv.set_linear_op(
    lambda K2, p: {
        "u": -jnp.exp(p["log_eps1"]) * K2,
        "v": -jnp.exp(p["log_eps2"]) * K2,
    }
)

def gs_nonlinear_inv(state_hat, p):
    u   = model_inv.inverse(state_hat["u"])
    v   = model_inv.inverse(state_hat["v"])
    uv2 = u * v**2
    b1  = jnp.exp(p["log_b1"]);  b2  = jnp.exp(p["log_b2"])
    c1  = jnp.exp(p["log_c1"]);  c2  = jnp.exp(p["log_c2"])
    return {
        "u": model_inv.forward(b1 * (1.0 - u) - c1 * uv2),
        "v": model_inv.forward(-b2 * v        + c2 * uv2),
    }

model_inv.set_nonlinear_op(gs_nonlinear_inv)

# Register log-parameters with perturbed initial guesses (~30% off true values)
model_inv.add_parameter("log_eps1", float(np.log(0.14)))   # true: log(0.20)
model_inv.add_parameter("log_eps2", float(np.log(0.07)))   # true: log(0.10)
model_inv.add_parameter("log_b1",   float(np.log(28.0)))   # true: log(40.0)
model_inv.add_parameter("log_b2",   float(np.log(70.0)))   # true: log(100.0)
model_inv.add_parameter("log_c1",   float(np.log(700.0)))  # true: log(1000.0)
model_inv.add_parameter("log_c2",   float(np.log(700.0)))  # true: log(1000.0)

model_inv.add_initial({"u": u0, "v": v0})

# Observation times must be registered for interpolation inside the solve loop
model_inv._obs_times = t_ref

# %%
# ── Dataset: scattered (x, y, t) observations of both u and v ────────────────
XX_grid, YY_grid, TT_grid = np.meshgrid(x_ref, y_ref, t_ref, indexing='ij')

X_obs = np.stack([
    XX_grid.ravel(),
    YY_grid.ravel(),
    TT_grid.ravel(),
], axis=-1).astype(np.float32)

U_obs_flat = U_noisy.transpose(1, 2, 0).ravel().astype(np.float32)
V_obs_flat = V_noisy.transpose(1, 2, 0).ravel().astype(np.float32)

n_obs = 8192
idx   = rng_np.choice(len(X_obs), size=n_obs, replace=False)

dataset = pinns.Dataset()
dataset.add_points(X_obs[idx], U_obs_flat[idx], name="obs_u", component=0)
dataset.add_points(X_obs[idx], V_obs_flat[idx], name="obs_v", component=1)

# ── Reference interpolants ────────────────────────────────────────────────────
def uv_reference_inv(X):
    pts = np.asarray(X)[:, :3]
    return np.concatenate([
        _interp_u(pts)[:, None],
        _interp_v(pts)[:, None],
    ], axis=1)

# ── Trainer ───────────────────────────────────────────────────────────────────
trainer_inv = pinns.Trainer(model_inv, dataset=dataset)
trainer_inv.add_solution(uv_reference_inv)

# True log-values as reference lines in the convergence plot
for name, true_val in [
    ("log_eps1", np.log(0.20)), ("log_eps2", np.log(0.10)),
    ("log_b1",   np.log(40.0)), ("log_b2",   np.log(100.0)),
    ("log_c1",   np.log(1000.0)), ("log_c2", np.log(1000.0)),
]:
    trainer_inv.add_parameter_solution(name, float(true_val))

trainer_inv.compile(
    fit_model_parameters=["log_eps1", "log_eps2", "log_b1", "log_b2", "log_c1", "log_c2"],
    optimizer=pinns.AdamOptimizer(learning_rate=1e-2),
    epochs=500,
    print_each=1,
    show=pinns.TrainPlotter(
        time_points=[0.0, 0.5, 1.0, 1.5, 2.0]
    )
)

trainer_inv.train()

# ── Recover physical parameters after training ────────────────────────────────
p_trained = trainer_inv.get_model_parameters()
print("\nRecovered parameters:")
for log_name, true_val in [
    ("log_eps1", 0.20), ("log_eps2", 0.10),
    ("log_b1",   40.0), ("log_b2",  100.0),
    ("log_c1", 1000.0), ("log_c2", 1000.0),
]:
    name = log_name[4:]   # strip "log_"
    recovered = float(np.exp(p_trained[log_name]))
    print(f"  {name:5s}: true={true_val:8.3f}  recovered={recovered:8.3f}  "
          f"rel_err={abs(recovered - true_val)/true_val*100:.1f}%")
# Out:
# Starting training for 500 epochs (JIT-compiled)...
# Epoch 0/500 | Loss: 5.18e-02 | MSE: 5.18e-02 | Terms: [] | Data: [obs_u: 3.96e-02, obs_v: 1.21e-02] | Error: N/A | Params: [log_eps1: -1.96611, log_eps2: -2.65926, log_b1: 3.3322, log_b2: 4.2485, log_c1: 6.55108, log_c2: 6.55108] | Time: 0.0s
# Epoch 1/500 | Loss: 8.82e-02 | MSE: 8.82e-02 | Terms: [] | Data: [obs_u: 6.86e-02, obs_v: 1.96e-02] | Error: N/A | Params: [log_eps1: -1.95611, log_eps2: -2.66926, log_b1: 3.3422, log_b2: 4.23849, log_c1: 6.54108, log_c2: 6.56108] | Time: 119.5s
# Epoch 2/500 | Loss: 1.15e-01 | MSE: 1.15e-01 | Terms: [] | Data: [obs_u: 8.99e-02, obs_v: 2.50e-02] | Error: N/A | Params: [log_eps1: -1.95005, log_eps2: -2.67588, log_b1: 3.34692, log_b2: 4.23369, log_c1: 6.53628, log_c2: 6.5659] | Time: 238.8s
# Epoch 3/500 | Loss: 1.27e-01 | MSE: 1.27e-01 | Terms: [] | Data: [obs_u: 9.93e-02, obs_v: 2.73e-02] | Error: N/A | Params: [log_eps1: -1.94563, log_eps2: -2.68117, log_b1: 3.3492, log_b2: 4.23125, log_c1: 6.53383, log_c2: 6.5684] | Time: 352.1s
# Epoch 4/500 | Loss: 1.32e-01 | MSE: 1.32e-01 | Terms: [] | Data: [obs_u: 1.04e-01, obs_v: 2.85e-02] | Error: N/A | Params: [log_eps1: -1.94222, log_eps2: -2.6857, log_b1: 3.35011, log_b2: 4.23014, log_c1: 6.53274, log_c2: 6.56955] | Time: 393.2s
# Epoch 5/500 | Loss: 1.32e-01 | MSE: 1.32e-01 | Terms: [] | Data: [obs_u: 1.04e-01, obs_v: 2.85e-02] | Error: N/A | Params: [log_eps1: -1.93951, log_eps2: -2.6897, log_b1: 3.35003, log_b2: 4.23001, log_c1: 6.53264, log_c2: 6.56973] | Time: 434.1s
# Epoch 6/500 | Loss: 1.29e-01 | MSE: 1.29e-01 | Terms: [] | Data: [obs_u: 1.01e-01, obs_v: 2.78e-02] | Error: N/A | Params: [log_eps1: -1.93734, log_eps2: -2.69332, log_b1: 3.34917, log_b2: 4.23064, log_c1: 6.53331, log_c2: 6.56914] | Time: 475.0s
# Epoch 7/500 | Loss: 1.25e-01 | MSE: 1.25e-01 | Terms: [] | Data: [obs_u: 9.78e-02, obs_v: 2.69e-02] | Error: N/A | Params: [log_eps1: -1.93563, log_eps2: -2.69666, log_b1: 3.34765, log_b2: 4.23192, log_c1: 6.53464, log_c2: 6.56791] | Time: 516.3s
# Epoch 8/500 | Loss: 1.14e-01 | MSE: 1.14e-01 | Terms: [] | Data: [obs_u: 8.89e-02, obs_v: 2.48e-02] | Error: N/A | Params: [log_eps1: -1.93428, log_eps2: -2.69975, log_b1: 3.34548, log_b2: 4.23383, log_c1: 6.5366, log_c2: 6.56605] | Time: 557.2s
# Epoch 9/500 | Loss: 1.01e-01 | MSE: 1.01e-01 | Terms: [] | Data: [obs_u: 7.90e-02, obs_v: 2.23e-02] | Error: N/A | Params: [log_eps1: -1.9333, log_eps2: -2.70263, log_b1: 3.3427, log_b2: 4.23633, log_c1: 6.53913, log_c2: 6.56362] | Time: 598.5s
# Epoch 10/500 | Loss: 8.28e-02 | MSE: 8.28e-02 | Terms: [] | Data: [obs_u: 6.39e-02, obs_v: 1.88e-02] | Error: N/A | Params: [log_eps1: -1.93275, log_eps2: -2.70522, log_b1: 3.33939, log_b2: 4.23937, log_c1: 6.54221, log_c2: 6.56064] | Time: 639.7s
# Epoch 11/500 | Loss: 5.94e-02 | MSE: 5.94e-02 | Terms: [] | Data: [obs_u: 4.42e-02, obs_v: 1.52e-02] | Error: N/A | Params: [log_eps1: -1.93275, log_eps2: -2.70736, log_b1: 3.33547, log_b2: 4.24304, log_c1: 6.54594, log_c2: 6.557] | Time: 680.8s
# Epoch 12/500 | Loss: 2.67e-02 | MSE: 2.67e-02 | Terms: [] | Data: [obs_u: 1.93e-02, obs_v: 7.41e-03] | Error: N/A | Params: [log_eps1: -1.93342, log_eps2: -2.70867, log_b1: 3.33089, log_b2: 4.24738, log_c1: 6.55031, log_c2: 6.55271] | Time: 722.1s
# Epoch 13/500 | Loss: 9.84e-02 | MSE: 9.84e-02 | Terms: [] | Data: [obs_u: 7.69e-02, obs_v: 2.15e-02] | Error: N/A | Params: [log_eps1: -1.93394, log_eps2: -2.70912, log_b1: 3.32517, log_b2: 4.2527, log_c1: 6.55547, log_c2: 6.54762] | Time: 763.1s
# Epoch 14/500 | Loss: 1.26e-01 | MSE: 1.26e-01 | Terms: [] | Data: [obs_u: 9.94e-02, obs_v: 2.67e-02] | Error: N/A | Params: [log_eps1: -1.93125, log_eps2: -2.7124, log_b1: 3.32238, log_b2: 4.25489, log_c1: 6.55741, log_c2: 6.54576] | Time: 804.1s
# Epoch 15/500 | Loss: 1.28e-01 | MSE: 1.28e-01 | Terms: [] | Data: [obs_u: 1.01e-01, obs_v: 2.71e-02] | Error: N/A | Params: [log_eps1: -1.9269, log_eps2: -2.71716, log_b1: 3.32128, log_b2: 4.25531, log_c1: 6.55754, log_c2: 6.54572] | Time: 845.3s
# Epoch 16/500 | Loss: 1.06e-01 | MSE: 1.06e-01 | Terms: [] | Data: [obs_u: 8.28e-02, obs_v: 2.31e-02] | Error: N/A | Params: [log_eps1: -1.92131, log_eps2: -2.72305, log_b1: 3.32159, log_b2: 4.25425, log_c1: 6.55618, log_c2: 6.54716] | Time: 886.3s
# Epoch 17/500 | Loss: 5.72e-02 | MSE: 5.72e-02 | Terms: [] | Data: [obs_u: 4.35e-02, obs_v: 1.37e-02] | Error: N/A | Params: [log_eps1: -1.91464, log_eps2: -2.72994, log_b1: 3.32341, log_b2: 4.2517, log_c1: 6.55331, log_c2: 6.55011] | Time: 927.5s
# Epoch 18/500 | Loss: 2.94e-02 | MSE: 2.94e-02 | Terms: [] | Data: [obs_u: 2.14e-02, obs_v: 8.02e-03] | Error: N/A | Params: [log_eps1: -1.90708, log_eps2: -2.73766, log_b1: 3.32687, log_b2: 4.24759, log_c1: 6.54892, log_c2: 6.55456] | Time: 968.6s
# Epoch 19/500 | Loss: 5.63e-02 | MSE: 5.63e-02 | Terms: [] | Data: [obs_u: 4.15e-02, obs_v: 1.47e-02] | Error: N/A | Params: [log_eps1: -1.90049, log_eps2: -2.74405, log_b1: 3.32905, log_b2: 4.24468, log_c1: 6.54568, log_c2: 6.55787] | Time: 1009.5s
# Epoch 20/500 | Loss: 7.03e-02 | MSE: 7.03e-02 | Terms: [] | Data: [obs_u: 5.25e-02, obs_v: 1.78e-02] | Error: N/A | Params: [log_eps1: -1.89485, log_eps2: -2.74952, log_b1: 3.33031, log_b2: 4.24273, log_c1: 6.54343, log_c2: 6.56018] | Time: 1050.7s
# Epoch 21/500 | Loss: 7.90e-02 | MSE: 7.90e-02 | Terms: [] | Data: [obs_u: 5.94e-02, obs_v: 1.96e-02] | Error: N/A | Params: [log_eps1: -1.89004, log_eps2: -2.75429, log_b1: 3.33084, log_b2: 4.24157, log_c1: 6.54201, log_c2: 6.56166] | Time: 1091.7s
# Epoch 22/500 | Loss: 8.12e-02 | MSE: 8.12e-02 | Terms: [] | Data: [obs_u: 6.13e-02, obs_v: 1.99e-02] | Error: N/A | Params: [log_eps1: -1.88595, log_eps2: -2.75851, log_b1: 3.33075, log_b2: 4.24108, log_c1: 6.54131, log_c2: 6.56242] | Time: 1132.7s
# Epoch 23/500 | Loss: 8.28e-02 | MSE: 8.28e-02 | Terms: [] | Data: [obs_u: 6.25e-02, obs_v: 2.03e-02] | Error: N/A | Params: [log_eps1: -1.88251, log_eps2: -2.76227, log_b1: 3.33019, log_b2: 4.24112, log_c1: 6.5412, log_c2: 6.56259] | Time: 1173.9s
# Epoch 24/500 | Loss: 7.98e-02 | MSE: 7.98e-02 | Terms: [] | Data: [obs_u: 5.99e-02, obs_v: 1.99e-02] | Error: N/A | Params: [log_eps1: -1.87965, log_eps2: -2.76559, log_b1: 3.32915, log_b2: 4.24169, log_c1: 6.54164, log_c2: 6.56221] | Time: 1214.9s
# Epoch 25/500 | Loss: 7.41e-02 | MSE: 7.41e-02 | Terms: [] | Data: [obs_u: 5.53e-02, obs_v: 1.88e-02] | Error: N/A | Params: [log_eps1: -1.87733, log_eps2: -2.76851, log_b1: 3.32765, log_b2: 4.24276, log_c1: 6.54262, log_c2: 6.56129] | Time: 1256.0s
# Epoch 26/500 | Loss: 6.43e-02 | MSE: 6.43e-02 | Terms: [] | Data: [obs_u: 4.75e-02, obs_v: 1.68e-02] | Error: N/A | Params: [log_eps1: -1.87554, log_eps2: -2.771, log_b1: 3.32568, log_b2: 4.24433, log_c1: 6.54413, log_c2: 6.55984] | Time: 1297.0s
# Epoch 27/500 | Loss: 4.98e-02 | MSE: 4.98e-02 | Terms: [] | Data: [obs_u: 3.65e-02, obs_v: 1.33e-02] | Error: N/A | Params: [log_eps1: -1.87427, log_eps2: -2.77301, log_b1: 3.32323, log_b2: 4.2464, log_c1: 6.54616, log_c2: 6.55787] | Time: 1338.0s
# Epoch 28/500 | Loss: 9.86e-03 | MSE: 9.86e-03 | Terms: [] | Data: [obs_u: 6.71e-03, obs_v: 3.15e-03] | Error: N/A | Params: [log_eps1: -1.87354, log_eps2: -2.7742, log_b1: 3.31963, log_b2: 4.24956, log_c1: 6.54918, log_c2: 6.55488] | Time: 1379.2s
# Epoch 29/500 | Loss: 5.60e-02 | MSE: 5.60e-02 | Terms: [] | Data: [obs_u: 4.23e-02, obs_v: 1.37e-02] | Error: N/A | Params: [log_eps1: -1.87311, log_eps2: -2.7739, log_b1: 3.31407, log_b2: 4.25449, log_c1: 6.55376, log_c2: 6.55035] | Time: 1420.2s
# Epoch 30/500 | Loss: 9.32e-02 | MSE: 9.32e-02 | Terms: [] | Data: [obs_u: 7.20e-02, obs_v: 2.12e-02] | Error: N/A | Params: [log_eps1: -1.87082, log_eps2: -2.77536, log_b1: 3.31045, log_b2: 4.25738, log_c1: 6.55624, log_c2: 6.54791] | Time: 1461.2s
# Epoch 31/500 | Loss: 1.06e-01 | MSE: 1.06e-01 | Terms: [] | Data: [obs_u: 8.20e-02, obs_v: 2.37e-02] | Error: N/A | Params: [log_eps1: -1.86698, log_eps2: -2.77839, log_b1: 3.30835, log_b2: 4.25868, log_c1: 6.55706, log_c2: 6.54712] | Time: 1502.4s
# Epoch 32/500 | Loss: 1.01e-01 | MSE: 1.01e-01 | Terms: [] | Data: [obs_u: 7.78e-02, obs_v: 2.27e-02] | Error: N/A | Params: [log_eps1: -1.86191, log_eps2: -2.78268, log_b1: 3.30746, log_b2: 4.25871, log_c1: 6.55657, log_c2: 6.54764] | Time: 1543.3s
# Epoch 33/500 | Loss: 7.91e-02 | MSE: 7.91e-02 | Terms: [] | Data: [obs_u: 6.05e-02, obs_v: 1.86e-02] | Error: N/A | Params: [log_eps1: -1.85582, log_eps2: -2.78801, log_b1: 3.3077, log_b2: 4.25758, log_c1: 6.5549, log_c2: 6.54934] | Time: 1584.3s
# Epoch 34/500 | Loss: 3.98e-02 | MSE: 3.98e-02 | Terms: [] | Data: [obs_u: 2.94e-02, obs_v: 1.04e-02] | Error: N/A | Params: [log_eps1: -1.84886, log_eps2: -2.7942, log_b1: 3.30902, log_b2: 4.25535, log_c1: 6.5521, log_c2: 6.55217] | Time: 1625.5s
# Epoch 35/500 | Loss: 7.32e-03 | MSE: 7.32e-03 | Terms: [] | Data: [obs_u: 4.89e-03, obs_v: 2.43e-03] | Error: N/A | Params: [log_eps1: -1.84135, log_eps2: -2.80092, log_b1: 3.31133, log_b2: 4.25216, log_c1: 6.54836, log_c2: 6.55592] | Time: 1666.5s
# Epoch 36/500 | Loss: 4.33e-02 | MSE: 4.33e-02 | Terms: [] | Data: [obs_u: 3.14e-02, obs_v: 1.19e-02] | Error: N/A | Params: [log_eps1: -1.83448, log_eps2: -2.80685, log_b1: 3.31345, log_b2: 4.24921, log_c1: 6.54491, log_c2: 6.5594] | Time: 1707.8s
# Epoch 37/500 | Loss: 5.63e-02 | MSE: 5.63e-02 | Terms: [] | Data: [obs_u: 4.12e-02, obs_v: 1.51e-02] | Error: N/A | Params: [log_eps1: -1.82872, log_eps2: -2.81154, log_b1: 3.31401, log_b2: 4.2478, log_c1: 6.54297, log_c2: 6.56136] | Time: 1748.8s
# Epoch 38/500 | Loss: 6.35e-02 | MSE: 6.35e-02 | Terms: [] | Data: [obs_u: 4.65e-02, obs_v: 1.70e-02] | Error: N/A | Params: [log_eps1: -1.82382, log_eps2: -2.81538, log_b1: 3.31361, log_b2: 4.24739, log_c1: 6.54205, log_c2: 6.56229] | Time: 1789.8s
# Epoch 39/500 | Loss: 6.13e-02 | MSE: 6.13e-02 | Terms: [] | Data: [obs_u: 4.49e-02, obs_v: 1.64e-02] | Error: N/A | Params: [log_eps1: -1.8197, log_eps2: -2.8185, log_b1: 3.31264, log_b2: 4.24763, log_c1: 6.54183, log_c2: 6.56252] | Time: 1831.1s
# Epoch 40/500 | Loss: 4.83e-02 | MSE: 4.83e-02 | Terms: [] | Data: [obs_u: 3.50e-02, obs_v: 1.33e-02] | Error: N/A | Params: [log_eps1: -1.81625, log_eps2: -2.82033, log_b1: 3.30984, log_b2: 4.2496, log_c1: 6.54329, log_c2: 6.56107] | Time: 1886.5s
# Epoch 41/500 | Loss: 1.57e-02 | MSE: 1.57e-02 | Terms: [] | Data: [obs_u: 1.09e-02, obs_v: 4.83e-03] | Error: N/A | Params: [log_eps1: -1.81355, log_eps2: -2.82146, log_b1: 3.30656, log_b2: 4.25211, log_c1: 6.54533, log_c2: 6.55904] | Time: 1931.4s
# Epoch 42/500 | Loss: 1.06e-02 | MSE: 1.06e-02 | Terms: [] | Data: [obs_u: 7.03e-03, obs_v: 3.62e-03] | Error: N/A | Params: [log_eps1: -1.81161, log_eps2: -2.82176, log_b1: 3.30301, log_b2: 4.25492, log_c1: 6.54775, log_c2: 6.55664] | Time: 1987.1s
# Epoch 43/500 | Loss: 2.57e-02 | MSE: 2.57e-02 | Terms: [] | Data: [obs_u: 1.81e-02, obs_v: 7.57e-03] | Error: N/A | Params: [log_eps1: -1.80951, log_eps2: -2.82219, log_b1: 3.30018, log_b2: 4.25708, log_c1: 6.54953, log_c2: 6.55488] | Time: 2032.2s
# Epoch 44/500 | Loss: 3.35e-02 | MSE: 3.35e-02 | Terms: [] | Data: [obs_u: 2.42e-02, obs_v: 9.38e-03] | Error: N/A | Params: [log_eps1: -1.80666, log_eps2: -2.82328, log_b1: 3.2984, log_b2: 4.25819, log_c1: 6.55027, log_c2: 6.55415] | Time: 2073.4s
# Epoch 45/500 | Loss: 3.15e-02 | MSE: 3.15e-02 | Terms: [] | Data: [obs_u: 2.25e-02, obs_v: 8.95e-03] | Error: N/A | Params: [log_eps1: -1.80298, log_eps2: -2.82516, log_b1: 3.29763, log_b2: 4.25829, log_c1: 6.54996, log_c2: 6.55446] | Time: 2114.3s
# Epoch 46/500 | Loss: 2.32e-02 | MSE: 2.32e-02 | Terms: [] | Data: [obs_u: 1.62e-02, obs_v: 7.07e-03] | Error: N/A | Params: [log_eps1: -1.79859, log_eps2: -2.82771, log_b1: 3.29774, log_b2: 4.25751, log_c1: 6.54875, log_c2: 6.55567] | Time: 2155.3s
# Epoch 47/500 | Loss: 1.19e-02 | MSE: 1.19e-02 | Terms: [] | Data: [obs_u: 7.76e-03, obs_v: 4.10e-03] | Error: N/A | Params: [log_eps1: -1.79382, log_eps2: -2.83059, log_b1: 3.29852, log_b2: 4.25608, log_c1: 6.54691, log_c2: 6.5575] | Time: 2196.6s
# Epoch 48/500 | Loss: 1.12e-02 | MSE: 1.12e-02 | Terms: [] | Data: [obs_u: 7.48e-03, obs_v: 3.74e-03] | Error: N/A | Params: [log_eps1: -1.78918, log_eps2: -2.83337, log_b1: 3.29966, log_b2: 4.25438, log_c1: 6.54482, log_c2: 6.55958] | Time: 2237.5s
# Epoch 49/500 | Loss: 2.02e-02 | MSE: 2.02e-02 | Terms: [] | Data: [obs_u: 1.40e-02, obs_v: 6.18e-03] | Error: N/A | Params: [log_eps1: -1.78537, log_eps2: -2.83531, log_b1: 3.30025, log_b2: 4.25325, log_c1: 6.54336, log_c2: 6.56103] | Time: 2278.5s
# Epoch 50/500 | Loss: 2.35e-02 | MSE: 2.35e-02 | Terms: [] | Data: [obs_u: 1.65e-02, obs_v: 7.05e-03] | Error: N/A | Params: [log_eps1: -1.7825, log_eps2: -2.83626, log_b1: 3.30011, log_b2: 4.25288, log_c1: 6.54271, log_c2: 6.56168] | Time: 2319.8s
# Epoch 51/500 | Loss: 2.14e-02 | MSE: 2.14e-02 | Terms: [] | Data: [obs_u: 1.49e-02, obs_v: 6.48e-03] | Error: N/A | Params: [log_eps1: -1.78057, log_eps2: -2.83627, log_b1: 3.29924, log_b2: 4.25325, log_c1: 6.54288, log_c2: 6.56152] | Time: 2360.8s
# Epoch 52/500 | Loss: 1.47e-02 | MSE: 1.47e-02 | Terms: [] | Data: [obs_u: 9.95e-03, obs_v: 4.77e-03] | Error: N/A | Params: [log_eps1: -1.77947, log_eps2: -2.83544, log_b1: 3.29771, log_b2: 4.2543, log_c1: 6.54377, log_c2: 6.56064] | Time: 2402.0s
# Epoch 53/500 | Loss: 9.69e-03 | MSE: 9.69e-03 | Terms: [] | Data: [obs_u: 6.24e-03, obs_v: 3.45e-03] | Error: N/A | Params: [log_eps1: -1.77899, log_eps2: -2.83396, log_b1: 3.29572, log_b2: 4.25581, log_c1: 6.54517, log_c2: 6.55927] | Time: 2443.0s
# Epoch 54/500 | Loss: 1.30e-02 | MSE: 1.30e-02 | Terms: [] | Data: [obs_u: 8.53e-03, obs_v: 4.51e-03] | Error: N/A | Params: [log_eps1: -1.77859, log_eps2: -2.83241, log_b1: 3.29397, log_b2: 4.25713, log_c1: 6.54639, log_c2: 6.55807] | Time: 2484.0s
# Epoch 55/500 | Loss: 1.77e-02 | MSE: 1.77e-02 | Terms: [] | Data: [obs_u: 1.19e-02, obs_v: 5.80e-03] | Error: N/A | Params: [log_eps1: -1.77781, log_eps2: -2.83118, log_b1: 3.29281, log_b2: 4.25788, log_c1: 6.54704, log_c2: 6.55744] | Time: 2525.3s
# Epoch 56/500 | Loss: 1.78e-02 | MSE: 1.78e-02 | Terms: [] | Data: [obs_u: 1.20e-02, obs_v: 5.84e-03] | Error: N/A | Params: [log_eps1: -1.77644, log_eps2: -2.83047, log_b1: 3.29235, log_b2: 4.25794, log_c1: 6.54697, log_c2: 6.55752] | Time: 2566.3s
# Epoch 57/500 | Loss: 1.45e-02 | MSE: 1.45e-02 | Terms: [] | Data: [obs_u: 9.58e-03, obs_v: 4.95e-03] | Error: N/A | Params: [log_eps1: -1.77458, log_eps2: -2.83019, log_b1: 3.2925, log_b2: 4.25741, log_c1: 6.5463, log_c2: 6.55819] | Time: 2607.3s
# Epoch 58/500 | Loss: 1.08e-02 | MSE: 1.08e-02 | Terms: [] | Data: [obs_u: 6.96e-03, obs_v: 3.88e-03] | Error: N/A | Params: [log_eps1: -1.77245, log_eps2: -2.83019, log_b1: 3.29311, log_b2: 4.25646, log_c1: 6.5452, log_c2: 6.55927] | Time: 2648.5s
# Epoch 59/500 | Loss: 1.04e-02 | MSE: 1.04e-02 | Terms: [] | Data: [obs_u: 6.83e-03, obs_v: 3.58e-03] | Error: N/A | Params: [log_eps1: -1.77038, log_eps2: -2.83019, log_b1: 3.29393, log_b2: 4.25535, log_c1: 6.54396, log_c2: 6.56049] | Time: 2689.5s
# Epoch 60/500 | Loss: 1.36e-02 | MSE: 1.36e-02 | Terms: [] | Data: [obs_u: 9.19e-03, obs_v: 4.44e-03] | Error: N/A | Params: [log_eps1: -1.76881, log_eps2: -2.82975, log_b1: 3.29447, log_b2: 4.25456, log_c1: 6.54307, log_c2: 6.56135] | Time: 2730.7s
# Epoch 61/500 | Loss: 1.48e-02 | MSE: 1.48e-02 | Terms: [] | Data: [obs_u: 1.00e-02, obs_v: 4.76e-03] | Error: N/A | Params: [log_eps1: -1.76794, log_eps2: -2.82861, log_b1: 3.29433, log_b2: 4.25444, log_c1: 6.54289, log_c2: 6.56153] | Time: 2771.6s
# Epoch 62/500 | Loss: 1.16e-02 | MSE: 1.16e-02 | Terms: [] | Data: [obs_u: 7.69e-03, obs_v: 3.87e-03] | Error: N/A | Params: [log_eps1: -1.76775, log_eps2: -2.82678, log_b1: 3.29353, log_b2: 4.25498, log_c1: 6.54338, log_c2: 6.56103] | Time: 2812.6s
# Epoch 63/500 | Loss: 9.57e-03 | MSE: 9.57e-03 | Terms: [] | Data: [obs_u: 6.17e-03, obs_v: 3.40e-03] | Error: N/A | Params: [log_eps1: -1.76805, log_eps2: -2.82449, log_b1: 3.29234, log_b2: 4.25591, log_c1: 6.5443, log_c2: 6.56011] | Time: 2853.8s
# Epoch 64/500 | Loss: 1.22e-02 | MSE: 1.22e-02 | Terms: [] | Data: [obs_u: 7.93e-03, obs_v: 4.30e-03] | Error: N/A | Params: [log_eps1: -1.76837, log_eps2: -2.82218, log_b1: 3.29129, log_b2: 4.25671, log_c1: 6.54511, log_c2: 6.55931] | Time: 2894.8s
# Epoch 65/500 | Loss: 1.29e-02 | MSE: 1.29e-02 | Terms: [] | Data: [obs_u: 8.46e-03, obs_v: 4.49e-03] | Error: N/A | Params: [log_eps1: -1.76842, log_eps2: -2.82018, log_b1: 3.29073, log_b2: 4.2571, log_c1: 6.54549, log_c2: 6.55891] | Time: 2935.8s
# Epoch 66/500 | Loss: 1.25e-02 | MSE: 1.25e-02 | Terms: [] | Data: [obs_u: 8.18e-03, obs_v: 4.37e-03] | Error: N/A | Params: [log_eps1: -1.76802, log_eps2: -2.81856, log_b1: 3.29069, log_b2: 4.25696, log_c1: 6.54533, log_c2: 6.55904] | Time: 2977.1s
# Epoch 67/500 | Loss: 1.03e-02 | MSE: 1.03e-02 | Terms: [] | Data: [obs_u: 6.62e-03, obs_v: 3.66e-03] | Error: N/A | Params: [log_eps1: -1.76725, log_eps2: -2.81729, log_b1: 3.29111, log_b2: 4.25639, log_c1: 6.54472, log_c2: 6.55961] | Time: 3018.1s
# Epoch 68/500 | Loss: 9.93e-03 | MSE: 9.93e-03 | Terms: [] | Data: [obs_u: 6.42e-03, obs_v: 3.51e-03] | Error: N/A | Params: [log_eps1: -1.76637, log_eps2: -2.81614, log_b1: 3.29177, log_b2: 4.25559, log_c1: 6.54389, log_c2: 6.56041] | Time: 3059.4s
# Epoch 69/500 | Loss: 1.04e-02 | MSE: 1.04e-02 | Terms: [] | Data: [obs_u: 6.93e-03, obs_v: 3.52e-03] | Error: N/A | Params: [log_eps1: -1.76566, log_eps2: -2.81491, log_b1: 3.29251, log_b2: 4.25478, log_c1: 6.54307, log_c2: 6.56118] | Time: 3100.4s
# Epoch 70/500 | Loss: 1.19e-02 | MSE: 1.19e-02 | Terms: [] | Data: [obs_u: 8.05e-03, obs_v: 3.90e-03] | Error: N/A | Params: [log_eps1: -1.76544, log_eps2: -2.81324, log_b1: 3.29283, log_b2: 4.2544, log_c1: 6.5427, log_c2: 6.5615] | Time: 3141.3s
# Epoch 71/500 | Loss: 1.05e-02 | MSE: 1.05e-02 | Terms: [] | Data: [obs_u: 6.96e-03, obs_v: 3.51e-03] | Error: N/A | Params: [log_eps1: -1.7658, log_eps2: -2.81098, log_b1: 3.29253, log_b2: 4.25461, log_c1: 6.54295, log_c2: 6.56122] | Time: 3182.6s
# Epoch 72/500 | Loss: 9.87e-03 | MSE: 9.87e-03 | Terms: [] | Data: [obs_u: 6.43e-03, obs_v: 3.45e-03] | Error: N/A | Params: [log_eps1: -1.76655, log_eps2: -2.80841, log_b1: 3.29195, log_b2: 4.25512, log_c1: 6.54353, log_c2: 6.5606] | Time: 3223.5s
# Epoch 73/500 | Loss: 9.01e-03 | MSE: 9.01e-03 | Terms: [] | Data: [obs_u: 5.82e-03, obs_v: 3.19e-03] | Error: N/A | Params: [log_eps1: -1.76741, log_eps2: -2.80585, log_b1: 3.29154, log_b2: 4.25555, log_c1: 6.54404, log_c2: 6.56005] | Time: 3264.5s
# Epoch 74/500 | Loss: 9.56e-03 | MSE: 9.56e-03 | Terms: [] | Data: [obs_u: 6.17e-03, obs_v: 3.39e-03] | Error: N/A | Params: [log_eps1: -1.76814, log_eps2: -2.80336, log_b1: 3.29131, log_b2: 4.25578, log_c1: 6.54436, log_c2: 6.55968] | Time: 3305.8s
# Epoch 75/500 | Loss: 1.08e-02 | MSE: 1.08e-02 | Terms: [] | Data: [obs_u: 6.99e-03, obs_v: 3.77e-03] | Error: N/A | Params: [log_eps1: -1.76862, log_eps2: -2.80111, log_b1: 3.29141, log_b2: 4.25569, log_c1: 6.54435, log_c2: 6.55964] | Time: 3346.8s
# Epoch 76/500 | Loss: 8.83e-03 | MSE: 8.83e-03 | Terms: [] | Data: [obs_u: 5.71e-03, obs_v: 3.12e-03] | Error: N/A | Params: [log_eps1: -1.76885, log_eps2: -2.79913, log_b1: 3.29189, log_b2: 4.25527, log_c1: 6.544, log_c2: 6.55991] | Time: 3388.0s
# Epoch 77/500 | Loss: 9.00e-03 | MSE: 9.00e-03 | Terms: [] | Data: [obs_u: 5.87e-03, obs_v: 3.14e-03] | Error: N/A | Params: [log_eps1: -1.76899, log_eps2: -2.79723, log_b1: 3.29254, log_b2: 4.25469, log_c1: 6.5435, log_c2: 6.56035] | Time: 3429.0s
# Epoch 78/500 | Loss: 9.13e-03 | MSE: 9.13e-03 | Terms: [] | Data: [obs_u: 6.10e-03, obs_v: 3.03e-03] | Error: N/A | Params: [log_eps1: -1.76924, log_eps2: -2.79531, log_b1: 3.29328, log_b2: 4.25408, log_c1: 6.54297, log_c2: 6.56079] | Time: 3470.0s
# Epoch 79/500 | Loss: 9.25e-03 | MSE: 9.25e-03 | Terms: [] | Data: [obs_u: 6.19e-03, obs_v: 3.06e-03] | Error: N/A | Params: [log_eps1: -1.76987, log_eps2: -2.793, log_b1: 3.2936, log_b2: 4.25385, log_c1: 6.54286, log_c2: 6.56084] | Time: 3511.3s
# Epoch 80/500 | Loss: 8.73e-03 | MSE: 8.73e-03 | Terms: [] | Data: [obs_u: 5.79e-03, obs_v: 2.94e-03] | Error: N/A | Params: [log_eps1: -1.77088, log_eps2: -2.79038, log_b1: 3.2936, log_b2: 4.25397, log_c1: 6.54309, log_c2: 6.56053] | Time: 3552.3s
# Epoch 81/500 | Loss: 9.23e-03 | MSE: 9.23e-03 | Terms: [] | Data: [obs_u: 6.03e-03, obs_v: 3.19e-03] | Error: N/A | Params: [log_eps1: -1.77211, log_eps2: -2.78759, log_b1: 3.29348, log_b2: 4.25422, log_c1: 6.54349, log_c2: 6.56006] | Time: 3593.2s
# Epoch 82/500 | Loss: 7.95e-03 | MSE: 7.95e-03 | Terms: [] | Data: [obs_u: 5.18e-03, obs_v: 2.76e-03] | Error: N/A | Params: [log_eps1: -1.77332, log_eps2: -2.78494, log_b1: 3.29366, log_b2: 4.25426, log_c1: 6.5437, log_c2: 6.55976] | Time: 3634.4s
# Epoch 83/500 | Loss: 7.69e-03 | MSE: 7.69e-03 | Terms: [] | Data: [obs_u: 5.03e-03, obs_v: 2.66e-03] | Error: N/A | Params: [log_eps1: -1.77444, log_eps2: -2.78239, log_b1: 3.294, log_b2: 4.25416, log_c1: 6.54375, log_c2: 6.55961] | Time: 3675.4s
# Epoch 84/500 | Loss: 7.50e-03 | MSE: 7.50e-03 | Terms: [] | Data: [obs_u: 4.91e-03, obs_v: 2.59e-03] | Error: N/A | Params: [log_eps1: -1.77549, log_eps2: -2.77986, log_b1: 3.29441, log_b2: 4.25396, log_c1: 6.54372, log_c2: 6.55955] | Time: 3716.6s
# Epoch 85/500 | Loss: 7.26e-03 | MSE: 7.26e-03 | Terms: [] | Data: [obs_u: 4.79e-03, obs_v: 2.47e-03] | Error: N/A | Params: [log_eps1: -1.77646, log_eps2: -2.7774, log_b1: 3.29494, log_b2: 4.25364, log_c1: 6.54356, log_c2: 6.55962] | Time: 3757.6s
# Epoch 86/500 | Loss: 7.16e-03 | MSE: 7.16e-03 | Terms: [] | Data: [obs_u: 4.74e-03, obs_v: 2.41e-03] | Error: N/A | Params: [log_eps1: -1.77747, log_eps2: -2.77482, log_b1: 3.29539, log_b2: 4.25338, log_c1: 6.54346, log_c2: 6.55964] | Time: 3798.6s
# Epoch 87/500 | Loss: 7.02e-03 | MSE: 7.02e-03 | Terms: [] | Data: [obs_u: 4.65e-03, obs_v: 2.37e-03] | Error: N/A | Params: [log_eps1: -1.77861, log_eps2: -2.77209, log_b1: 3.2957, log_b2: 4.25324, log_c1: 6.54349, log_c2: 6.55954] | Time: 3839.9s
# Epoch 88/500 | Loss: 6.94e-03 | MSE: 6.94e-03 | Terms: [] | Data: [obs_u: 4.59e-03, obs_v: 2.35e-03] | Error: N/A | Params: [log_eps1: -1.77979, log_eps2: -2.7693, log_b1: 3.29598, log_b2: 4.25312, log_c1: 6.54354, log_c2: 6.55942] | Time: 3880.9s
# Epoch 89/500 | Loss: 6.78e-03 | MSE: 6.78e-03 | Terms: [] | Data: [obs_u: 4.51e-03, obs_v: 2.27e-03] | Error: N/A | Params: [log_eps1: -1.781, log_eps2: -2.76649, log_b1: 3.29629, log_b2: 4.25298, log_c1: 6.54358, log_c2: 6.55931] | Time: 3936.3s
# Epoch 90/500 | Loss: 7.34e-03 | MSE: 7.34e-03 | Terms: [] | Data: [obs_u: 4.85e-03, obs_v: 2.49e-03] | Error: N/A | Params: [log_eps1: -1.78224, log_eps2: -2.76355, log_b1: 3.29651, log_b2: 4.2529, log_c1: 6.54367, log_c2: 6.55916] | Time: 3981.1s
# Epoch 91/500 | Loss: 6.40e-03 | MSE: 6.40e-03 | Terms: [] | Data: [obs_u: 4.26e-03, obs_v: 2.14e-03] | Error: N/A | Params: [log_eps1: -1.78343, log_eps2: -2.76076, log_b1: 3.29698, log_b2: 4.25262, log_c1: 6.54358, log_c2: 6.55917] | Time: 4023.0s
# Epoch 92/500 | Loss: 6.34e-03 | MSE: 6.34e-03 | Terms: [] | Data: [obs_u: 4.24e-03, obs_v: 2.10e-03] | Error: N/A | Params: [log_eps1: -1.78468, log_eps2: -2.75792, log_b1: 3.29743, log_b2: 4.25237, log_c1: 6.54353, log_c2: 6.55916] | Time: 4064.4s
# Epoch 93/500 | Loss: 6.11e-03 | MSE: 6.11e-03 | Terms: [] | Data: [obs_u: 4.09e-03, obs_v: 2.02e-03] | Error: N/A | Params: [log_eps1: -1.78602, log_eps2: -2.75498, log_b1: 3.29778, log_b2: 4.25221, log_c1: 6.54357, log_c2: 6.55905] | Time: 4105.4s
# Epoch 94/500 | Loss: 5.75e-03 | MSE: 5.75e-03 | Terms: [] | Data: [obs_u: 3.86e-03, obs_v: 1.90e-03] | Error: N/A | Params: [log_eps1: -1.78744, log_eps2: -2.75196, log_b1: 3.29807, log_b2: 4.25211, log_c1: 6.54367, log_c2: 6.55888] | Time: 4146.4s
# Epoch 95/500 | Loss: 5.98e-03 | MSE: 5.98e-03 | Terms: [] | Data: [obs_u: 3.99e-03, obs_v: 2.00e-03] | Error: N/A | Params: [log_eps1: -1.78887, log_eps2: -2.74887, log_b1: 3.29829, log_b2: 4.25205, log_c1: 6.54381, log_c2: 6.55868] | Time: 4187.6s
# Epoch 96/500 | Loss: 5.61e-03 | MSE: 5.61e-03 | Terms: [] | Data: [obs_u: 3.76e-03, obs_v: 1.85e-03] | Error: N/A | Params: [log_eps1: -1.79022, log_eps2: -2.74593, log_b1: 3.29873, log_b2: 4.25181, log_c1: 6.54377, log_c2: 6.55865] | Time: 4228.6s
# Epoch 97/500 | Loss: 5.39e-03 | MSE: 5.39e-03 | Terms: [] | Data: [obs_u: 3.63e-03, obs_v: 1.76e-03] | Error: N/A | Params: [log_eps1: -1.79156, log_eps2: -2.743, log_b1: 3.29922, log_b2: 4.25153, log_c1: 6.54369, log_c2: 6.55866] | Time: 4269.6s
# Epoch 98/500 | Loss: 5.62e-03 | MSE: 5.62e-03 | Terms: [] | Data: [obs_u: 3.82e-03, obs_v: 1.80e-03] | Error: N/A | Params: [log_eps1: -1.79294, log_eps2: -2.74006, log_b1: 3.29971, log_b2: 4.25125, log_c1: 6.54362, log_c2: 6.55866] | Time: 4310.8s
# Epoch 99/500 | Loss: 5.15e-03 | MSE: 5.15e-03 | Terms: [] | Data: [obs_u: 3.49e-03, obs_v: 1.66e-03] | Error: N/A | Params: [log_eps1: -1.79445, log_eps2: -2.73687, log_b1: 3.29993, log_b2: 4.2512, log_c1: 6.54378, log_c2: 6.55845] | Time: 4352.0s
# Epoch 100/500 | Loss: 5.16e-03 | MSE: 5.16e-03 | Terms: [] | Data: [obs_u: 3.49e-03, obs_v: 1.67e-03] | Error: N/A | Params: [log_eps1: -1.796, log_eps2: -2.73359, log_b1: 3.30006, log_b2: 4.25121, log_c1: 6.54399, log_c2: 6.55818] | Time: 4393.3s
# Epoch 101/500 | Loss: 4.93e-03 | MSE: 4.93e-03 | Terms: [] | Data: [obs_u: 3.32e-03, obs_v: 1.61e-03] | Error: N/A | Params: [log_eps1: -1.79742, log_eps2: -2.73037, log_b1: 3.30027, log_b2: 4.25113, log_c1: 6.5441, log_c2: 6.55804] | Time: 4434.3s
# Epoch 102/500 | Loss: 4.63e-03 | MSE: 4.63e-03 | Terms: [] | Data: [obs_u: 3.15e-03, obs_v: 1.48e-03] | Error: N/A | Params: [log_eps1: -1.79863, log_eps2: -2.72733, log_b1: 3.30067, log_b2: 4.25082, log_c1: 6.54398, log_c2: 6.55812] | Time: 4475.3s
# Epoch 103/500 | Loss: 4.48e-03 | MSE: 4.48e-03 | Terms: [] | Data: [obs_u: 3.07e-03, obs_v: 1.41e-03] | Error: N/A | Params: [log_eps1: -1.79974, log_eps2: -2.72436, log_b1: 3.30115, log_b2: 4.25043, log_c1: 6.54376, log_c2: 6.5583] | Time: 4516.6s
# Epoch 104/500 | Loss: 4.55e-03 | MSE: 4.55e-03 | Terms: [] | Data: [obs_u: 3.15e-03, obs_v: 1.40e-03] | Error: N/A | Params: [log_eps1: -1.80095, log_eps2: -2.7213, log_b1: 3.30152, log_b2: 4.25016, log_c1: 6.54367, log_c2: 6.55836] | Time: 4557.6s
# Epoch 105/500 | Loss: 4.08e-03 | MSE: 4.08e-03 | Terms: [] | Data: [obs_u: 2.81e-03, obs_v: 1.27e-03] | Error: N/A | Params: [log_eps1: -1.80237, log_eps2: -2.71802, log_b1: 3.30161, log_b2: 4.25014, log_c1: 6.54382, log_c2: 6.55817] | Time: 4598.6s
# Epoch 106/500 | Loss: 4.04e-03 | MSE: 4.04e-03 | Terms: [] | Data: [obs_u: 2.77e-03, obs_v: 1.26e-03] | Error: N/A | Params: [log_eps1: -1.80379, log_eps2: -2.71479, log_b1: 3.30172, log_b2: 4.25011, log_c1: 6.54397, log_c2: 6.558] | Time: 4639.9s
# Epoch 107/500 | Loss: 3.89e-03 | MSE: 3.89e-03 | Terms: [] | Data: [obs_u: 2.67e-03, obs_v: 1.22e-03] | Error: N/A | Params: [log_eps1: -1.80507, log_eps2: -2.71168, log_b1: 3.30195, log_b2: 4.24995, log_c1: 6.54398, log_c2: 6.55795] | Time: 4680.8s
# Epoch 108/500 | Loss: 3.74e-03 | MSE: 3.74e-03 | Terms: [] | Data: [obs_u: 2.60e-03, obs_v: 1.14e-03] | Error: N/A | Params: [log_eps1: -1.80623, log_eps2: -2.70877, log_b1: 3.30236, log_b2: 4.24963, log_c1: 6.54383, log_c2: 6.55808] | Time: 4729.8s
# Epoch 109/500 | Loss: 3.66e-03 | MSE: 3.66e-03 | Terms: [] | Data: [obs_u: 2.57e-03, obs_v: 1.09e-03] | Error: N/A | Params: [log_eps1: -1.80744, log_eps2: -2.7058, log_b1: 3.30267, log_b2: 4.2494, log_c1: 6.54377, log_c2: 6.55811] | Time: 4777.8s
# Epoch 110/500 | Loss: 3.47e-03 | MSE: 3.47e-03 | Terms: [] | Data: [obs_u: 2.42e-03, obs_v: 1.05e-03] | Error: N/A | Params: [log_eps1: -1.80876, log_eps2: -2.70272, log_b1: 3.30278, log_b2: 4.24936, log_c1: 6.54388, log_c2: 6.55798] | Time: 4821.7s
# Epoch 111/500 | Loss: 3.38e-03 | MSE: 3.38e-03 | Terms: [] | Data: [obs_u: 2.35e-03, obs_v: 1.02e-03] | Error: N/A | Params: [log_eps1: -1.81006, log_eps2: -2.69971, log_b1: 3.30292, log_b2: 4.24929, log_c1: 6.54397, log_c2: 6.55787] | Time: 4863.0s
# Epoch 112/500 | Loss: 3.30e-03 | MSE: 3.30e-03 | Terms: [] | Data: [obs_u: 2.30e-03, obs_v: 1.00e-03] | Error: N/A | Params: [log_eps1: -1.81126, log_eps2: -2.69682, log_b1: 3.30315, log_b2: 4.24913, log_c1: 6.54396, log_c2: 6.55785] | Time: 4904.0s
# Epoch 113/500 | Loss: 3.23e-03 | MSE: 3.23e-03 | Terms: [] | Data: [obs_u: 2.28e-03, obs_v: 9.49e-04] | Error: N/A | Params: [log_eps1: -1.81242, log_eps2: -2.69403, log_b1: 3.30346, log_b2: 4.2489, log_c1: 6.54389, log_c2: 6.5579] | Time: 4944.9s
# Epoch 114/500 | Loss: 3.23e-03 | MSE: 3.23e-03 | Terms: [] | Data: [obs_u: 2.29e-03, obs_v: 9.37e-04] | Error: N/A | Params: [log_eps1: -1.81357, log_eps2: -2.69125, log_b1: 3.3037, log_b2: 4.24873, log_c1: 6.54386, log_c2: 6.55791] | Time: 4986.2s
# Epoch 115/500 | Loss: 3.20e-03 | MSE: 3.20e-03 | Terms: [] | Data: [obs_u: 2.27e-03, obs_v: 9.31e-04] | Error: N/A | Params: [log_eps1: -1.81476, log_eps2: -2.6884, log_b1: 3.30378, log_b2: 4.24868, log_c1: 6.54395, log_c2: 6.55781] | Time: 5027.2s
# Epoch 116/500 | Loss: 2.97e-03 | MSE: 2.97e-03 | Terms: [] | Data: [obs_u: 2.09e-03, obs_v: 8.75e-04] | Error: N/A | Params: [log_eps1: -1.81587, log_eps2: -2.68558, log_b1: 3.30383, log_b2: 4.24864, log_c1: 6.54403, log_c2: 6.55773] | Time: 5068.4s
# Epoch 117/500 | Loss: 2.85e-03 | MSE: 2.85e-03 | Terms: [] | Data: [obs_u: 2.03e-03, obs_v: 8.25e-04] | Error: N/A | Params: [log_eps1: -1.81681, log_eps2: -2.68298, log_b1: 3.30405, log_b2: 4.24843, log_c1: 6.54393, log_c2: 6.55782] | Time: 5109.4s
# Epoch 118/500 | Loss: 2.85e-03 | MSE: 2.85e-03 | Terms: [] | Data: [obs_u: 2.04e-03, obs_v: 8.06e-04] | Error: N/A | Params: [log_eps1: -1.8177, log_eps2: -2.68048, log_b1: 3.30432, log_b2: 4.24818, log_c1: 6.54379, log_c2: 6.55796] | Time: 5150.5s
# Epoch 119/500 | Loss: 2.72e-03 | MSE: 2.72e-03 | Terms: [] | Data: [obs_u: 1.95e-03, obs_v: 7.70e-04] | Error: N/A | Params: [log_eps1: -1.81869, log_eps2: -2.67791, log_b1: 3.30439, log_b2: 4.24812, log_c1: 6.54382, log_c2: 6.55792] | Time: 5191.7s
# Epoch 120/500 | Loss: 2.88e-03 | MSE: 2.88e-03 | Terms: [] | Data: [obs_u: 2.06e-03, obs_v: 8.25e-04] | Error: N/A | Params: [log_eps1: -1.81978, log_eps2: -2.67529, log_b1: 3.30431, log_b2: 4.24821, log_c1: 6.54401, log_c2: 6.55773] | Time: 5232.7s
# Epoch 121/500 | Loss: 2.75e-03 | MSE: 2.75e-03 | Terms: [] | Data: [obs_u: 1.97e-03, obs_v: 7.88e-04] | Error: N/A | Params: [log_eps1: -1.82064, log_eps2: -2.67289, log_b1: 3.3044, log_b2: 4.24811, log_c1: 6.54399, log_c2: 6.55775] | Time: 5274.0s
# Epoch 122/500 | Loss: 2.65e-03 | MSE: 2.65e-03 | Terms: [] | Data: [obs_u: 1.91e-03, obs_v: 7.42e-04] | Error: N/A | Params: [log_eps1: -1.82132, log_eps2: -2.67071, log_b1: 3.30466, log_b2: 4.24783, log_c1: 6.54379, log_c2: 6.55796] | Time: 5315.0s
# Epoch 123/500 | Loss: 2.71e-03 | MSE: 2.71e-03 | Terms: [] | Data: [obs_u: 1.95e-03, obs_v: 7.54e-04] | Error: N/A | Params: [log_eps1: -1.82203, log_eps2: -2.66852, log_b1: 3.3048, log_b2: 4.24767, log_c1: 6.54369, log_c2: 6.55806] | Time: 5355.9s
# Epoch 124/500 | Loss: 2.50e-03 | MSE: 2.50e-03 | Terms: [] | Data: [obs_u: 1.81e-03, obs_v: 6.94e-04] | Error: N/A | Params: [log_eps1: -1.82287, log_eps2: -2.66624, log_b1: 3.3047, log_b2: 4.24776, log_c1: 6.54382, log_c2: 6.55793] | Time: 5397.1s
# Epoch 125/500 | Loss: 2.72e-03 | MSE: 2.72e-03 | Terms: [] | Data: [obs_u: 1.96e-03, obs_v: 7.62e-04] | Error: N/A | Params: [log_eps1: -1.82365, log_eps2: -2.66407, log_b1: 3.30462, log_b2: 4.24781, log_c1: 6.54391, log_c2: 6.55784] | Time: 5438.1s
# Epoch 126/500 | Loss: 2.39e-03 | MSE: 2.39e-03 | Terms: [] | Data: [obs_u: 1.73e-03, obs_v: 6.55e-04] | Error: N/A | Params: [log_eps1: -1.82415, log_eps2: -2.66218, log_b1: 3.30478, log_b2: 4.2476, log_c1: 6.54374, log_c2: 6.55803] | Time: 5479.3s
# Epoch 127/500 | Loss: 2.70e-03 | MSE: 2.70e-03 | Terms: [] | Data: [obs_u: 1.97e-03, obs_v: 7.26e-04] | Error: N/A | Params: [log_eps1: -1.82467, log_eps2: -2.66032, log_b1: 3.30488, log_b2: 4.24746, log_c1: 6.54362, log_c2: 6.55815] | Time: 5520.3s
# Epoch 128/500 | Loss: 2.42e-03 | MSE: 2.42e-03 | Terms: [] | Data: [obs_u: 1.76e-03, obs_v: 6.61e-04] | Error: N/A | Params: [log_eps1: -1.82528, log_eps2: -2.65833, log_b1: 3.30476, log_b2: 4.24752, log_c1: 6.54368, log_c2: 6.5581] | Time: 5561.3s
# Epoch 129/500 | Loss: 2.48e-03 | MSE: 2.48e-03 | Terms: [] | Data: [obs_u: 1.80e-03, obs_v: 6.79e-04] | Error: N/A | Params: [log_eps1: -1.8258, log_eps2: -2.65645, log_b1: 3.30467, log_b2: 4.24754, log_c1: 6.5437, log_c2: 6.5581] | Time: 5602.6s
# Epoch 130/500 | Loss: 2.48e-03 | MSE: 2.48e-03 | Terms: [] | Data: [obs_u: 1.81e-03, obs_v: 6.69e-04] | Error: N/A | Params: [log_eps1: -1.82615, log_eps2: -2.6548, log_b1: 3.30475, log_b2: 4.24738, log_c1: 6.54353, log_c2: 6.55828] | Time: 5643.6s
# Epoch 131/500 | Loss: 2.65e-03 | MSE: 2.65e-03 | Terms: [] | Data: [obs_u: 1.95e-03, obs_v: 7.03e-04] | Error: N/A | Params: [log_eps1: -1.8265, log_eps2: -2.65316, log_b1: 3.30474, log_b2: 4.24731, log_c1: 6.54344, log_c2: 6.55839] | Time: 5684.6s
# Epoch 132/500 | Loss: 2.31e-03 | MSE: 2.31e-03 | Terms: [] | Data: [obs_u: 1.69e-03, obs_v: 6.21e-04] | Error: N/A | Params: [log_eps1: -1.8269, log_eps2: -2.65142, log_b1: 3.30454, log_b2: 4.24739, log_c1: 6.54349, log_c2: 6.55837] | Time: 5725.9s
# Epoch 133/500 | Loss: 2.71e-03 | MSE: 2.71e-03 | Terms: [] | Data: [obs_u: 1.98e-03, obs_v: 7.32e-04] | Error: N/A | Params: [log_eps1: -1.82726, log_eps2: -2.64976, log_b1: 3.30436, log_b2: 4.24746, log_c1: 6.54351, log_c2: 6.55836] | Time: 5766.9s
# Epoch 134/500 | Loss: 2.35e-03 | MSE: 2.35e-03 | Terms: [] | Data: [obs_u: 1.72e-03, obs_v: 6.32e-04] | Error: N/A | Params: [log_eps1: -1.82736, log_eps2: -2.64832, log_b1: 3.30437, log_b2: 4.24731, log_c1: 6.54331, log_c2: 6.5586] | Time: 5808.2s
# Epoch 135/500 | Loss: 2.46e-03 | MSE: 2.46e-03 | Terms: [] | Data: [obs_u: 1.80e-03, obs_v: 6.58e-04] | Error: N/A | Params: [log_eps1: -1.82749, log_eps2: -2.64694, log_b1: 3.30436, log_b2: 4.2472, log_c1: 6.54314, log_c2: 6.55879] | Time: 5849.3s
# Epoch 136/500 | Loss: 2.31e-03 | MSE: 2.31e-03 | Terms: [] | Data: [obs_u: 1.69e-03, obs_v: 6.19e-04] | Error: N/A | Params: [log_eps1: -1.82781, log_eps2: -2.64543, log_b1: 3.30408, log_b2: 4.24736, log_c1: 6.54324, log_c2: 6.55871] | Time: 5890.3s
# Epoch 137/500 | Loss: 2.46e-03 | MSE: 2.46e-03 | Terms: [] | Data: [obs_u: 1.80e-03, obs_v: 6.58e-04] | Error: N/A | Params: [log_eps1: -1.82803, log_eps2: -2.64407, log_b1: 3.30391, log_b2: 4.24743, log_c1: 6.54324, log_c2: 6.55873] | Time: 5931.6s
# Epoch 138/500 | Loss: 2.28e-03 | MSE: 2.28e-03 | Terms: [] | Data: [obs_u: 1.69e-03, obs_v: 5.99e-04] | Error: N/A | Params: [log_eps1: -1.82804, log_eps2: -2.64293, log_b1: 3.30393, log_b2: 4.24729, log_c1: 6.54302, log_c2: 6.55897] | Time: 5972.6s
# Epoch 139/500 | Loss: 2.33e-03 | MSE: 2.33e-03 | Terms: [] | Data: [obs_u: 1.73e-03, obs_v: 6.04e-04] | Error: N/A | Params: [log_eps1: -1.82812, log_eps2: -2.64175, log_b1: 3.30382, log_b2: 4.24728, log_c1: 6.54292, log_c2: 6.5591] | Time: 6013.8s
# Epoch 140/500 | Loss: 2.48e-03 | MSE: 2.48e-03 | Terms: [] | Data: [obs_u: 1.83e-03, obs_v: 6.55e-04] | Error: N/A | Params: [log_eps1: -1.8283, log_eps2: -2.64046, log_b1: 3.30352, log_b2: 4.24745, log_c1: 6.54299, log_c2: 6.55905] | Time: 6054.8s
# Epoch 141/500 | Loss: 2.27e-03 | MSE: 2.27e-03 | Terms: [] | Data: [obs_u: 1.67e-03, obs_v: 5.98e-04] | Error: N/A | Params: [log_eps1: -1.82829, log_eps2: -2.63937, log_b1: 3.30339, log_b2: 4.24743, log_c1: 6.54287, log_c2: 6.55919] | Time: 6095.9s
# Epoch 142/500 | Loss: 2.28e-03 | MSE: 2.28e-03 | Terms: [] | Data: [obs_u: 1.69e-03, obs_v: 5.87e-04] | Error: N/A | Params: [log_eps1: -1.82822, log_eps2: -2.63837, log_b1: 3.30333, log_b2: 4.24735, log_c1: 6.54269, log_c2: 6.55941] | Time: 6137.2s
# Epoch 143/500 | Loss: 2.18e-03 | MSE: 2.18e-03 | Terms: [] | Data: [obs_u: 1.61e-03, obs_v: 5.73e-04] | Error: N/A | Params: [log_eps1: -1.82825, log_eps2: -2.63729, log_b1: 3.3031, log_b2: 4.24744, log_c1: 6.54266, log_c2: 6.55946] | Time: 6192.0s
# Epoch 144/500 | Loss: 2.44e-03 | MSE: 2.44e-03 | Terms: [] | Data: [obs_u: 1.78e-03, obs_v: 6.66e-04] | Error: N/A | Params: [log_eps1: -1.82835, log_eps2: -2.63621, log_b1: 3.30283, log_b2: 4.24757, log_c1: 6.54269, log_c2: 6.55946] | Time: 6236.6s
# Epoch 145/500 | Loss: 2.22e-03 | MSE: 2.22e-03 | Terms: [] | Data: [obs_u: 1.64e-03, obs_v: 5.73e-04] | Error: N/A | Params: [log_eps1: -1.82824, log_eps2: -2.63543, log_b1: 3.30285, log_b2: 4.24745, log_c1: 6.54245, log_c2: 6.55972] | Time: 6277.7s
# Epoch 146/500 | Loss: 2.36e-03 | MSE: 2.36e-03 | Terms: [] | Data: [obs_u: 1.76e-03, obs_v: 6.04e-04] | Error: N/A | Params: [log_eps1: -1.82826, log_eps2: -2.63455, log_b1: 3.3027, log_b2: 4.2475, log_c1: 6.54238, log_c2: 6.5598] | Time: 6318.7s
# Epoch 147/500 | Loss: 2.24e-03 | MSE: 2.24e-03 | Terms: [] | Data: [obs_u: 1.65e-03, obs_v: 5.94e-04] | Error: N/A | Params: [log_eps1: -1.82831, log_eps2: -2.63362, log_b1: 3.30243, log_b2: 4.24765, log_c1: 6.54241, log_c2: 6.5598] | Time: 6360.0s
# Epoch 148/500 | Loss: 2.16e-03 | MSE: 2.16e-03 | Terms: [] | Data: [obs_u: 1.60e-03, obs_v: 5.66e-04] | Error: N/A | Params: [log_eps1: -1.82826, log_eps2: -2.63285, log_b1: 3.30231, log_b2: 4.24766, log_c1: 6.54229, log_c2: 6.55993] | Time: 6401.1s
# Epoch 149/500 | Loss: 2.28e-03 | MSE: 2.28e-03 | Terms: [] | Data: [obs_u: 1.70e-03, obs_v: 5.84e-04] | Error: N/A | Params: [log_eps1: -1.82821, log_eps2: -2.63214, log_b1: 3.30223, log_b2: 4.24764, log_c1: 6.54215, log_c2: 6.56009] | Time: 6442.4s
# Epoch 150/500 | Loss: 2.17e-03 | MSE: 2.17e-03 | Terms: [] | Data: [obs_u: 1.60e-03, obs_v: 5.71e-04] | Error: N/A | Params: [log_eps1: -1.8282, log_eps2: -2.63137, log_b1: 3.30203, log_b2: 4.24773, log_c1: 6.5421, log_c2: 6.56015] | Time: 6483.3s
# Epoch 151/500 | Loss: 2.27e-03 | MSE: 2.27e-03 | Terms: [] | Data: [obs_u: 1.66e-03, obs_v: 6.07e-04] | Error: N/A | Params: [log_eps1: -1.82822, log_eps2: -2.63064, log_b1: 3.30186, log_b2: 4.24783, log_c1: 6.54207, log_c2: 6.5602] | Time: 6524.3s
# Epoch 152/500 | Loss: 2.22e-03 | MSE: 2.22e-03 | Terms: [] | Data: [obs_u: 1.65e-03, obs_v: 5.71e-04] | Error: N/A | Params: [log_eps1: -1.82818, log_eps2: -2.63008, log_b1: 3.30185, log_b2: 4.24778, log_c1: 6.54189, log_c2: 6.56038] | Time: 6565.6s
# Epoch 153/500 | Loss: 2.19e-03 | MSE: 2.19e-03 | Terms: [] | Data: [obs_u: 1.62e-03, obs_v: 5.70e-04] | Error: N/A | Params: [log_eps1: -1.82821, log_eps2: -2.62945, log_b1: 3.3017, log_b2: 4.24787, log_c1: 6.54185, log_c2: 6.56043] | Time: 6606.7s
# Epoch 154/500 | Loss: 2.25e-03 | MSE: 2.25e-03 | Terms: [] | Data: [obs_u: 1.66e-03, obs_v: 5.82e-04] | Error: N/A | Params: [log_eps1: -1.82827, log_eps2: -2.62883, log_b1: 3.30153, log_b2: 4.24799, log_c1: 6.54184, log_c2: 6.56045] | Time: 6647.7s
# Epoch 155/500 | Loss: 2.26e-03 | MSE: 2.26e-03 | Terms: [] | Data: [obs_u: 1.66e-03, obs_v: 6.00e-04] | Error: N/A | Params: [log_eps1: -1.82822, log_eps2: -2.62832, log_b1: 3.30147, log_b2: 4.24799, log_c1: 6.54171, log_c2: 6.56059] | Time: 6703.6s
# Epoch 156/500 | Loss: 2.19e-03 | MSE: 2.19e-03 | Terms: [] | Data: [obs_u: 1.62e-03, obs_v: 5.64e-04] | Error: N/A | Params: [log_eps1: -1.82821, log_eps2: -2.62787, log_b1: 3.30144, log_b2: 4.24799, log_c1: 6.54158, log_c2: 6.56072] | Time: 6746.3s
# Epoch 157/500 | Loss: 2.20e-03 | MSE: 2.20e-03 | Terms: [] | Data: [obs_u: 1.63e-03, obs_v: 5.74e-04] | Error: N/A | Params: [log_eps1: -1.82834, log_eps2: -2.62732, log_b1: 3.30127, log_b2: 4.24814, log_c1: 6.5416, log_c2: 6.56069] | Time: 6789.7s
# Epoch 158/500 | Loss: 2.36e-03 | MSE: 2.36e-03 | Terms: [] | Data: [obs_u: 1.73e-03, obs_v: 6.30e-04] | Error: N/A | Params: [log_eps1: -1.82836, log_eps2: -2.62691, log_b1: 3.30123, log_b2: 4.24818, log_c1: 6.54151, log_c2: 6.56079] | Time: 6830.7s
# Epoch 159/500 | Loss: 2.22e-03 | MSE: 2.22e-03 | Terms: [] | Data: [obs_u: 1.66e-03, obs_v: 5.60e-04] | Error: N/A | Params: [log_eps1: -1.82831, log_eps2: -2.62662, log_b1: 3.30129, log_b2: 4.24812, log_c1: 6.54131, log_c2: 6.56097] | Time: 6871.7s
