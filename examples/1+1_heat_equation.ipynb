# %% [markdown]
# # Heat Equation with PINNs
#
# This notebook demonstrates how to solve the **1D heat equation** using Physics-Informed Neural Networks (PINNs).
#
# ## The Problem
#
# We solve the heat diffusion equation:
#
# $$\frac{\partial u}{\partial t} = \alpha \frac{\partial^2 u}{\partial x^2}$$
#
# with:
# - **Domain**: $x \in [0, 1]$, $t \in [0, 1]$
# - **Boundary conditions**: $u(0, t) = u(1, t) = 0$
# - **Initial condition**: $u(x, 0) = \sin(\pi x)$
#
# ## Analytical Solution
#
# The analytical solution is:
#
# $$u(x, t) = e^{-\alpha \pi^2 t} \sin(\pi x)$$
#
# We will compare our PINN solution against this analytical result.

# %%
import pinns
pinns.use_backend('jax')  # or 'torch'
# pinns.use_backend('torch')  # or 'torch'
import numpy as np
import matplotlib.pyplot as plt
# Out:
# pinns: Using jax backend

# %% [markdown]
# ## 1. Define Parameters
#
# The thermal diffusivity $\alpha$ controls how fast heat spreads. A larger value means faster diffusion.

# %%
# Physical parameter
alpha = 0.1  # Thermal diffusivity

# Domain bounds
x_min, x_max = 0.0, 1.0
t_min, t_max = 0.0, 1.0

# %% [markdown]
# ## 2. Define the Domain
#
# We create a 2D domain for $(x, t)$ and use Latin Hypercube Sampling for better coverage of the domain.

# %%
domain = pinns.DomainCubic(
    xmin=[x_min, t_min],
    xmax=[x_max, t_max]
)

print(f"Domain dimensions: {domain.n_dims}")
print(f"Domain bounds: x ∈ [{x_min}, {x_max}], t ∈ [{t_min}, {t_max}]")
# Out:
# Domain dimensions: 2
# Domain bounds: x ∈ [0.0, 1.0], t ∈ [0.0, 1.0]

# %% [markdown]
# ## 3. Add Boundary Conditions
#
# We have three boundary conditions:
# 1. **Left boundary**: $u(0, t) = 0$
# 2. **Right boundary**: $u(1, t) = 0$
# 3. **Initial condition**: $u(x, 0) = \sin(\pi x)$

# %%
# Left boundary: u(0, t) = 0
domain.add_dirichlet(
    boundary=(0, None),  # x = x_min, all t
    value=0.0,
    component=0,
    name="left"
)

# Right boundary: u(1, t) = 0
domain.add_dirichlet(
    boundary=(1, None),  # x = x_max, all t
    value=0.0,
    component=0,
    name="right"
)

# Initial condition: u(x, 0) = sin(pi * x)
# Note: value function receives numpy array, so use np.sin
domain.add_dirichlet(
    boundary=(None, 0),  # all x, t = t_min
    value=lambda x: np.sin(np.pi * x[:, 0:1]),
    component=0,
    name="initial"
)

print(f"Number of boundary conditions: {len(domain.boundary_conditions)}")
# Out:
# Number of boundary conditions: 3

# %% [markdown]
# ## 4. Define the PDE Residual
#
# The PDE residual is the equation that should equal zero when the PDE is satisfied:
#
# $$\text{residual} = \frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} = 0$$

# %%
def heat_equation(X, V, params, derivative=None):
    """
    Heat equation residual.
    
    Args:
        X: Input tensor (batch, 2) with columns [x, t]
        V: Network output (batch, 1) with column [u]
        params: Dictionary with 'fixed', 'infer', 'internal' keys
        derivative: Function to compute derivatives (for JIT compatibility)
    
    Returns:
        Residual tensor (should be zero when PDE is satisfied)
    """
    # Use passed derivative for JIT, fallback to pinns.derivative
    if derivative is None:
        derivative = pinns.derivative
    
    alpha = params["fixed"]["alpha"]
    
    # Compute derivatives using automatic differentiation
    u_t = derivative(V, X, component=0, order=(1,))    # ∂u/∂t
    u_xx = derivative(V, X, component=0, order=(0, 0)) # ∂²u/∂x²
    
    # Heat equation: u_t = alpha * u_xx
    return u_t - alpha * u_xx

# %% [markdown]
# ## 5. Define the Analytical Solution (for comparison)
#
# Since we know the analytical solution, we can provide it to the trainer for error visualization.

# %%
def analytical_solution(X, params):
    """
    Analytical solution: u(x, t) = exp(-alpha * pi^2 * t) * sin(pi * x)
    """
    alpha = params["fixed"]["alpha"]
    x = X[:, 0:1]
    t = X[:, 1:2]
    
    return np.exp(-alpha * np.pi**2 * t) * np.sin(np.pi * x)

# %% [markdown]
# ## 6. Create the Problem
#
# The `Problem` class combines the domain, PDE, and parameters into a single object.

# %%
problem = pinns.Problem(
    domain=domain,
    pde_fn=heat_equation,
    input_names=["x", "t"],
    output_names=["u"],
    output_range=(0, 1),  # Expected output range for normalization
    params={"alpha": alpha},
    solution=analytical_solution  # For error tracking
)

print(f"Problem: {problem.n_dims}D input → {problem.n_outputs}D output")
# Out:
# Problem: 2D input → 1D output

# %% [markdown]
# ## 7. Create the Neural Network
#
# We use a fully-connected network with 3 hidden layers of 64 neurons each.
#
# The `tanh` activation is commonly used in PINNs as it provides smooth derivatives.

# %%
network = pinns.FNN(
    layer_sizes=[2, 64, 64, 64, 1],  # 2 inputs → 64 → 64 → 64 → 1 output
    activation="tanh",
    normalize_input=True,
    unnormalize_output=True
)

# Count parameters
# n_params = sum(p.numel() for p in network.parameters())
# print(f"Network architecture: {network.layer_sizes}")
# print(f"Total parameters: {n_params:,}")

# %% [markdown]
# ## 8. Create the Trainer
#
# The `Trainer` handles the training loop, sampling, and visualization.

# %%
trainer = pinns.Trainer(problem, network)
# print(f"Training on device: {trainer.device}")

# %% [markdown]
# ## 9. Configure and Train
#
# We use:
# - More samples for the PDE (interior) than boundaries
# - Higher weights for boundary conditions to enforce them more strongly
# - Adam optimizer for initial training

# %%
from matplotlib.colors import LogNorm

# %%
trainer.compile(
    train_samples={
        "pde": 5000,      # Interior PDE samples
        "left": 200,      # Left boundary samples
        "right": 200,     # Right boundary samples
        "initial": 500    # Initial condition samples
    },
    test_samples={
        "pde": 500,
        "left": 50,
        "right": 50,
        "initial": 100
    },
    weights={
        "pde": 1.0,
        "left": 10.0,     # Higher weight for BCs
        "right": 10.0,
        "initial": 50.0   # Highest weight for IC
    },
    optimizer="adam",
    learning_rate=1e-3,
    epochs=10000,
    print_each=500,
    plot_kwargs={
        "residuals": {"norm": LogNorm(vmin=1e-3, vmax=1e0)}
    },
    show_plots=True
)

trainer.train()
# Out:
# Starting training for 10000 epochs (JIT-compiled)...
# Epoch 0/10000 | Loss: 3.27e+00 | MSE Loss: 3.27e+00 | PDE: 1.47e-01 | BCs: [left: 4.75e-01, right: 5.89e-01, initial: 2.06e+00] | Time: 0.0s | Test Loss: 8.08e-01 | Error: 6.41e-01
# Epoch 500/10000 | Loss: 2.70e-02 | MSE Loss: 2.70e-02 | PDE: 2.62e-02 | BCs: [left: 2.28e-04, right: 4.02e-04, initial: 1.67e-04] | Time: 6.5s | Test Loss: 2.44e-02 | Error: 3.77e-02
# Epoch 1000/10000 | Loss: 4.64e-03 | MSE Loss: 4.64e-03 | PDE: 4.51e-03 | BCs: [left: 2.26e-05, right: 7.43e-05, initial: 3.63e-05] | Time: 10.1s | Test Loss: 4.22e-03 | Error: 9.16e-03
# Epoch 1500/10000 | Loss: 1.86e-03 | MSE Loss: 1.86e-03 | PDE: 1.80e-03 | BCs: [left: 8.78e-06, right: 2.84e-05, initial: 2.06e-05] | Time: 13.5s | Test Loss: 1.77e-03 | Error: 6.17e-03
# Epoch 2000/10000 | Loss: 1.27e-03 | MSE Loss: 1.27e-03 | PDE: 1.18e-03 | BCs: [left: 2.20e-05, right: 2.50e-05, initial: 4.08e-05] | Time: 17.0s | Test Loss: 1.24e-03 | Error: 6.12e-03
# Epoch 2500/10000 | Loss: 8.12e-04 | MSE Loss: 8.12e-04 | PDE: 7.89e-04 | BCs: [left: 5.02e-06, right: 9.89e-06, initial: 8.30e-06] | Time: 20.4s | Test Loss: 8.53e-04 | Error: 3.68e-03
# Epoch 3000/10000 | Loss: 1.29e-03 | MSE Loss: 1.29e-03 | PDE: 8.11e-04 | BCs: [left: 5.42e-05, right: 1.08e-04, initial: 3.15e-04] | Time: 24.0s | Test Loss: 9.73e-04 | Error: 9.42e-03
# Epoch 3500/10000 | Loss: 5.07e-04 | MSE Loss: 5.07e-04 | PDE: 4.95e-04 | BCs: [left: 3.69e-06, right: 4.73e-06, initial: 4.21e-06] | Time: 27.5s | Test Loss: 5.50e-04 | Error: 2.59e-03
# Epoch 4000/10000 | Loss: 1.04e-03 | MSE Loss: 1.04e-03 | PDE: 5.16e-04 | BCs: [left: 1.93e-05, right: 2.37e-05, initial: 4.79e-04] | Time: 31.0s | Test Loss: 6.14e-04 | Error: 9.03e-03
# Epoch 4500/10000 | Loss: 6.38e-04 | MSE Loss: 6.38e-04 | PDE: 4.03e-04 | BCs: [left: 1.10e-05, right: 1.10e-05, initial: 2.13e-04] | Time: 34.5s | Test Loss: 4.62e-04 | Error: 6.45e-03
# Epoch 5000/10000 | Loss: 2.95e-04 | MSE Loss: 2.95e-04 | PDE: 2.89e-04 | BCs: [left: 2.05e-06, right: 2.31e-06, initial: 1.64e-06] | Time: 38.0s | Test Loss: 3.25e-04 | Error: 1.73e-03
# Epoch 5500/10000 | Loss: 2.56e-04 | MSE Loss: 2.56e-04 | PDE: 2.51e-04 | BCs: [left: 1.70e-06, right: 2.03e-06, initial: 1.34e-06] | Time: 40.6s | Test Loss: 2.80e-04 | Error: 1.59e-03
# Epoch 6000/10000 | Loss: 2.27e-04 | MSE Loss: 2.27e-04 | PDE: 2.19e-04 | BCs: [left: 1.49e-06, right: 1.82e-06, initial: 4.35e-06] | Time: 43.2s | Test Loss: 2.40e-04 | Error: 1.77e-03
# Epoch 6500/10000 | Loss: 1.91e-04 | MSE Loss: 1.91e-04 | PDE: 1.87e-04 | BCs: [left: 1.14e-06, right: 1.68e-06, initial: 9.64e-07] | Time: 45.9s | Test Loss: 2.06e-04 | Error: 1.30e-03
# Epoch 7000/10000 | Loss: 1.80e-04 | MSE Loss: 1.80e-04 | PDE: 1.77e-04 | BCs: [left: 1.18e-06, right: 1.68e-06, initial: 9.42e-07] | Time: 49.4s | Test Loss: 1.91e-04 | Error: 1.27e-03
# Epoch 7500/10000 | Loss: 2.71e-04 | MSE Loss: 2.71e-04 | PDE: 1.96e-04 | BCs: [left: 3.52e-06, right: 6.14e-06, initial: 6.54e-05] | Time: 52.9s | Test Loss: 2.05e-04 | Error: 3.63e-03
# Epoch 8000/10000 | Loss: 2.19e-04 | MSE Loss: 2.19e-04 | PDE: 1.61e-04 | BCs: [left: 2.42e-06, right: 4.04e-06, initial: 5.16e-05] | Time: 56.5s | Test Loss: 1.68e-04 | Error: 3.47e-03
# Epoch 8500/10000 | Loss: 2.14e-04 | MSE Loss: 2.14e-04 | PDE: 1.23e-04 | BCs: [left: 2.91e-05, right: 2.86e-05, initial: 3.31e-05] | Time: 59.2s | Test Loss: 1.64e-04 | Error: 4.95e-03
# Epoch 9000/10000 | Loss: 1.13e-04 | MSE Loss: 1.13e-04 | PDE: 1.10e-04 | BCs: [left: 5.28e-07, right: 1.13e-06, initial: 6.11e-07] | Time: 62.6s | Test Loss: 1.17e-04 | Error: 9.95e-04
# Epoch 9500/10000 | Loss: 1.10e-04 | MSE Loss: 1.10e-04 | PDE: 1.08e-04 | BCs: [left: 4.88e-07, right: 1.08e-06, initial: 6.78e-07] | Time: 65.4s | Test Loss: 1.13e-04 | Error: 9.53e-04
# Epoch 10000/10000 | Loss: 1.23e-04 | MSE Loss: 1.23e-04 | PDE: 1.14e-04 | BCs: [left: 5.13e-07, right: 1.34e-06, initial: 6.34e-06] | Time: 68.9s | Test Loss: 1.14e-04 | Error: 1.01e-03
# Training complete in 69.9s

# %% [markdown]
# ## 10. Fine-tune with L-BFGS (Optional)
#
# L-BFGS often provides better convergence for the final refinement phase.

# %%
trainer.compile(
    optimizer="lbfgs",
    epochs=500,
    print_each=50,
    show_plots=True,
    plot_kwargs={
        "residuals": {"norm": LogNorm(vmin=1e-3, vmax=1e0)}
    },
    plot_style={
        "theme": "dark"
    }
)

trainer.train()
# Out:
# Starting L-BFGS training for 500 epochs (5 iterations per epoch, history=50)...
# Epoch 0/10500 | Loss: 1.27e-04 | MSE Loss: 1.27e-04 | PDE: 1.19e-04 | BCs: [left: 4.96e-07, right: 1.40e-06, initial: 6.54e-06] | Time: 0.0s | Test Loss: 9.68e-05 | Error: 1.10e-03
# Epoch 10050/10500 | Loss: 7.75e-05 | MSE Loss: 7.75e-05 | PDE: 7.33e-05 | BCs: [left: 2.03e-07, right: 4.41e-07, initial: 1.88e-07] | Time: 4.5s | Test Loss: 6.92e-05 | Error: 9.70e-04
# Epoch 10100/10500 | Loss: 5.47e-05 | MSE Loss: 5.47e-05 | PDE: 5.05e-05 | BCs: [left: 3.59e-07, right: 1.49e-07, initial: 3.26e-07] | Time: 5.6s | Test Loss: 4.85e-05 | Error: 7.77e-04
# Epoch 10150/10500 | Loss: 3.38e-05 | MSE Loss: 3.38e-05 | PDE: 2.89e-05 | BCs: [left: 5.92e-07, right: 2.13e-07, initial: 1.82e-07] | Time: 6.9s | Test Loss: 2.99e-05 | Error: 6.24e-04
# Epoch 10200/10500 | Loss: 2.56e-05 | MSE Loss: 2.56e-05 | PDE: 2.20e-05 | BCs: [left: 4.69e-07, right: 1.68e-07, initial: 8.64e-08] | Time: 8.0s | Test Loss: 2.12e-05 | Error: 4.08e-04
# Epoch 10250/10500 | Loss: 1.84e-05 | MSE Loss: 1.84e-05 | PDE: 1.46e-05 | BCs: [left: 5.14e-07, right: 1.28e-07, initial: 1.12e-07] | Time: 9.1s | Test Loss: 1.42e-05 | Error: 4.14e-04
# Epoch 10300/10500 | Loss: 1.56e-05 | MSE Loss: 1.56e-05 | PDE: 1.24e-05 | BCs: [left: 4.56e-07, right: 9.11e-08, initial: 8.14e-08] | Time: 10.2s | Test Loss: 1.14e-05 | Error: 4.15e-04
# Epoch 10350/10500 | Loss: 1.40e-05 | MSE Loss: 1.40e-05 | PDE: 1.11e-05 | BCs: [left: 3.67e-07, right: 1.04e-07, initial: 1.07e-07] | Time: 11.5s | Test Loss: 1.08e-05 | Error: 3.55e-04
# Epoch 10400/10500 | Loss: 1.20e-05 | MSE Loss: 1.20e-05 | PDE: 9.73e-06 | BCs: [left: 2.32e-07, right: 1.11e-07, initial: 1.07e-07] | Time: 12.7s | Test Loss: 9.67e-06 | Error: 3.21e-04
# Epoch 10450/10500 | Loss: 1.07e-05 | MSE Loss: 1.07e-05 | PDE: 8.87e-06 | BCs: [left: 1.70e-07, right: 1.11e-07, initial: 8.20e-08] | Time: 13.9s | Test Loss: 8.90e-06 | Error: 2.85e-04
# Epoch 10500/10500 | Loss: 9.32e-06 | MSE Loss: 9.32e-06 | PDE: 8.07e-06 | BCs: [left: 1.46e-07, right: 6.87e-08, initial: 3.37e-08] | Time: 15.2s | Test Loss: 8.06e-06 | Error: 2.71e-04
# L-BFGS training complete in 16.3s
